# %% [markdown]
# # Выборка и агрегация данных в MongoDB
#
# ### Цель домашней работы
#
# Закрепить на практике основные приемы работы с СУБД MongoDB, включая выборку, сортировку, объединение, агрегацию данных и передачу результатов выборки в программу на Python в целях аналитики и дальнейшей обработки.

# %% [markdown]
# ### Формулировка задания
#
# В этом задании вам предстоит выполнить несколько запросов к базе данных для получения выборок по условиям, а также воспользоваться фреймворком агрегации MongoDB для построения конвейера обработки данных.
#
# Максимальное количество баллов за выполнение домашней работы: 10.

# %% [markdown]
# ## Что нужно использовать в работе над заданием
#
# I. MongoDB:
#
# 1. Зарегистрируйтесь в сервисе MongoDB Atlas: https://www.mongodb.com/atlas/database.
# 1. Создайте кластер уровня M0 (это бесплатно).
# 1. Добавьте в кластер тестовую базу данных `sample_mflix`, используя опцию Load Sample Dataset.
#
# В качестве альтернативы вы можете установить MongoDB на свой локальный компьютер и импортировать необходимые датасеты в свою СУБД, загрузив их по ссылке: https://github.com/neelabalan/mongodb-sample-dataset/tree/main/sample_mflix. Для этого подключитесь к своему серверу через Compass, создайте новую БД, создайте для каждого датасета коллекцию и щелкните «Add data» → «Import JSON or CSV file».
#
# II. MongoDB Compass — в качестве вспомогательного инструмента для конструирования запросов и агрегаций.
#
# III. Python и библиотека pymongo. Работа ведется в Jupyter Notebook или Google Colaboratory. Рекомендуется использовать версию Python 3.12.

# %% [markdown]
# ## Ожидаемые результаты
#
# Результаты работы необходимо оформить в виде ноутбука Jupyter. Можно загрузить файл в LMS либо поделиться ссылкой на Google Colaboratory.

# %% [markdown]
# ## Место где нужно выполнить задание

# %%
#Начать выполнение задания тут
import json

with open('../keys.json', 'r') as f:
    keys = json.load(f)['mongodb']

# %%
# !pip install pymongo

import pymongo

client = pymongo.MongoClient("mongodb+srv://{}:{}@{}".format(keys['user'], keys['password'], keys['address']))
print(client.list_database_names())  # Вывести список БД для проверки подключения
# Out:
# Requirement already satisfied: pymongo in /home/artempris/miniconda3/envs/dsps/lib/python3.10/site-packages (4.6.2)
# Requirement already satisfied: dnspython<3.0.0,>=1.16.0 in /home/artempris/miniconda3/envs/dsps/lib/python3.10/site-packages (from pymongo) (2.6.1)
# ['sample_airbnb', 'sample_analytics', 'sample_geospatial', 'sample_guides', 'sample_mflix', 'sample_restaurants', 'sample_supplies', 'sample_training', 'sample_weatherdata', 'admin', 'local']

# %%
db = client.sample_mflix

# %%
list(db.list_collections())
# Out:
# [{'name': 'sessions',
#   'type': 'collection',
#   'options': {},
#   'info': {'readOnly': False,
#    'uuid': Binary(b'\x05\x12\xc5\xbc\xaf\x18G\x1e\xb6 "\x96\xf4\x1ft\x9d', 4)},
#   'idIndex': {'v': 2, 'key': {'_id': 1}, 'name': '_id_'}},
#  {'name': 'embedded_movies',
#   'type': 'collection',
#   'options': {},
#   'info': {'readOnly': False,
#    'uuid': Binary(b'\t\x03\xa6\x974\xd8Fm\xb5O\xf8\x9c\xe2L\xf8K', 4)},
#   'idIndex': {'v': 2, 'key': {'_id': 1}, 'name': '_id_'}},
#  {'name': 'comments',
#   'type': 'collection',
#   'options': {},
#   'info': {'readOnly': False,
#    'uuid': Binary(b'h\x0e\x94\x1a\x163D\xf1\x93\xd7\xb1\x9b\x9d\xa5\x9f\x9e', 4)},
#   'idIndex': {'v': 2, 'key': {'_id': 1}, 'name': '_id_'}},
#  {'name': 'theaters',
#   'type': 'collection',
#   'options': {},
#   'info': {'readOnly': False,
#    'uuid': Binary(b'\xbeV?\xb3\xfb\x85C\xc7\xb7\x9a\xad\xb5\x00\xf5\xe3\x88', 4)},
#   'idIndex': {'v': 2, 'key': {'_id': 1}, 'name': '_id_'}},
#  {'name': 'movies',
#   'type': 'collection',
#   'options': {},
#   'info': {'readOnly': False,
#    'uuid': Binary(b'\xceD\x03\xbe\x1a+L\x97\x89\xdd\xf5ipBg\xe4', 4)},
#   'idIndex': {'v': 2, 'key': {'_id': 1}, 'name': '_id_'}},
#  {'name': 'users',
#   'type': 'collection',
#   'options': {},
#   'info': {'readOnly': False,
#    'uuid': Binary(b'\xd0\xca\xd3\xd9-\xb3G\xcb\x8b\x1dyLt\x02m\xbd', 4)},
#   'idIndex': {'v': 2, 'key': {'_id': 1}, 'name': '_id_'}}]

# %% [markdown]
# ### Упражнение 1. Запросы на выборку

# %% [markdown]
# Цель этого упражнения — закрепить навык выполнения запросов на выборку. Все запросы выполняются на базе `sample_mflix` с данными о кинофильмах.

# %% [markdown]
# #### Задача 1.1 — **1 балл**

# %% [markdown]
# Выведите из коллекции `theaters` документы о кинотеатрах в городе Florence, штат KY.
#
# Для справки:
#
# * Обратите внимание на то, что информация об адресе кинотеатров хранится во вложенных документах. Для доступа к полям вложенных документов следует использовать точку: `родительский_документ.вложенный_документ.поле`.
# * В случае затруднений с написанием логического условия обращайтесь к сопоставлению синтаксиса SQL и Mongo: https://www.mongodb.com/docs/manual/reference/sql-comparison/.
# * Если вы предпочитаете сперва выполнять запросы в Compass, из этого приложения можно выгружать код готового запроса на Python (кнопка с символом `</>`).

# %%
# Ваш код здесь
theaters = db.theaters

list(theaters.find({'location.address.city': 'Florence', 'location.address.state': 'KY'}))
# Out:
# [{'_id': ObjectId('59a47287cfa9a3a73e51e893'),
#   'theaterId': 161,
#   'location': {'address': {'street1': '100 Meijer Dr.',
#     'city': 'Florence',
#     'state': 'KY',
#     'zipcode': '41042'},
#    'geo': {'type': 'Point', 'coordinates': [-84.636383, 39.014843]}}},
#  {'_id': ObjectId('59a47287cfa9a3a73e51ea02'),
#   'theaterId': 2823,
#   'location': {'address': {'street1': '2823 Florence Mall',
#     'street2': '#2148',
#     'city': 'Florence',
#     'state': 'KY',
#     'zipcode': '41042'},
#    'geo': {'type': 'Point', 'coordinates': [-84.6499595, 38.9967246]}}}]

# %% [markdown]
# #### Задача 1.2 — **1 балл**

# %% [markdown]
# Сделав запрос к коллекции `comments`, выведите _один_ комментарий (значение поля `text`) пользователя по имени Doreah.

# %%
# Ваш код здесь
comments = db.comments

comments.find_one({'name': 'Doreah'})['text']
# Out:
# 'Porro explicabo cumque vitae sint quia quis. Consequuntur voluptatibus optio maxime ratione temporibus incidunt minus architecto.'

# %% [markdown]
# #### Задача 1.3 — **1 балл**

# %% [markdown]
# Сделав запрос к коллекции `movies`, выведите количество документов, в которых в качестве первого жанра фильма (поле `genres`) указано значение «Horror».
#
# Для справки:
#
# 1. Обратите внимание, что поле `genres` представляет собой массив (индексация массивов начинается с нуля).
# 1. При работе в MongoDB Shell для подсчета количества документов в курсоре можно использовать метод `count()`, однако он был удален в последних версиях библиотеки pymongo. В случае затруднений с использованием функций Mongo можно использовать для подсчета документов средства Python.

# %%
# Ваш код здесь
movies = db.movies

len(list(movies.find({'genres.0': 'Horror'}))) # count() не сработал
# Out:
# 700

# %% [markdown]
# #### Задача 1.4 — **2 балла**

# %% [markdown]
# Выведите из коллекции `movies` документы о фильмах, которые в качестве первого жанра определены как «Film-Noir» либо «Horror» и были выпущены в период с 1940 по 1949 гг. (включительно).

# %%
# Ваш код здесь
movies = db.movies
list(movies.find({'$and': [{'genres.0': {'$in': ['Film-Noir', 'Horror']}},
                           {'year': {'$gte': 1940, '$lte': 1949}}]}))
# Out:
# [{'_id': ObjectId('573a1393f29313caabcdcdf5'),
#   'plot': 'A seemingly tame leopard used for a publicity stunt escapes and kills a young girl, spreading panic throughout a sleepy new Mexico town.',
#   'genres': ['Horror', 'Thriller'],
#   'runtime': 66,
#   'rated': 'APPROVED',
#   'cast': ["Dennis O'Keefe", 'Margo', 'Jean Brooks', 'Isabel Jewell'],
#   'num_mflix_comments': 0,
#   'poster': 'https://m.media-amazon.com/images/M/MV5BYmU4ZDI5NGMtYzM1OC00YTQ3LWI1NTEtNGM0Mzc0ZDA5NzI4XkEyXkFqcGdeQXVyMTQxNzMzNDI@._V1_SY1000_SX677_AL_.jpg',
#   'title': 'The Leopard Man',
#   'fullplot': 'At the encouragement of her manager, a nightclub performer in New Mexico (Kiki Walker) takes a leashed leopard into the club as a publicity gimmick. But her rival, angered by the attempt to upstage, scares the animal and it bolts. In the days that follow, people are mauled and the countryside is combed for the loose creature. But Kiki and her manager begin to wonder if maybe the leopard is not responsible for the killings.',
#   'languages': ['English', 'Spanish'],
#   'released': datetime.datetime(1943, 5, 8, 0, 0),
#   'directors': ['Jacques Tourneur'],
#   'writers': ['Ardel Wray (screenplay)',
#    'Edward Dein (additional dialogue)',
#    'Cornell Woolrich (novel)'],
#   'awards': {'wins': 0, 'nominations': 2, 'text': '2 nominations.'},
#   'lastupdated': '2015-08-05 00:17:53.897000000',
#   'year': 1943,
#   'imdb': {'rating': 6.9, 'votes': 2889, 'id': 36104},
#   'countries': ['USA'],
#   'type': 'movie',
#   'tomatoes': {'viewer': {'rating': 3.5, 'numReviews': 1375, 'meter': 67},
#    'fresh': 15,
#    'critic': {'rating': 7.4, 'numReviews': 17, 'meter': 88},
#    'rotten': 2,
#    'lastUpdated': datetime.datetime(2015, 8, 27, 18, 6, 2)}},
#  {'_id': ObjectId('573a1393f29313caabcdd6e7'),
#   'plot': "Chuck Scott gets a job as chauffeur to tough guy Eddie Roman; but Chuck's involvement with Eddie's fearful wife becomes a nightmare.",
#   'genres': ['Film-Noir'],
#   'runtime': 86,
#   'rated': 'APPROVED',
#   'cast': ['Robert Cummings',
#    'Michèle Morgan',
#    'Steve Cochran',
#    'Lloyd Corrigan'],
#   'num_mflix_comments': 0,
#   'poster': 'https://m.media-amazon.com/images/M/MV5BNDI3OTM4NzMtNzQxMC00M2YxLWFmOTctNmUyNDBmMzIwZGI0XkEyXkFqcGdeQXVyMjUxODE0MDY@._V1_SY1000_SX677_AL_.jpg',
#   'title': 'The Chase',
#   'fullplot': "Returning a lost wallet gains unemployed veteran Chuck Scott a job as chauffeur to Eddie Roman, a seeming gangster whose enemies have a way of meeting violent ends. The job proves nerve-wracking, and soon Chuck finds himself pledged to help Eddie's lovely, fearful, prisoner-wife Lorna to escape. The result leaves Chuck caught like a rat in a trap, vainly seeking a way out through dark streets. But the real chase begins when the strange plot virtually starts all over again...",
#   'languages': ['English', 'Spanish'],
#   'released': datetime.datetime(1946, 11, 16, 0, 0),
#   'directors': ['Arthur Ripley'],
#   'writers': ['Philip Yordan (written for the screen by)',
#    'Cornell Woolrich (book)'],
#   'awards': {'wins': 0, 'nominations': 1, 'text': '1 nomination.'},
#   'lastupdated': '2015-08-01 00:47:13.267000000',
#   'year': 1946,
#   'imdb': {'rating': 6.7, 'votes': 766, 'id': 38409},
#   'countries': ['USA'],
#   'type': 'movie',
#   'tomatoes': {'viewer': {'rating': 3.2, 'numReviews': 92, 'meter': 40},
#    'dvd': datetime.datetime(2003, 8, 5, 0, 0),
#    'production': 'VCI',
#    'lastUpdated': datetime.datetime(2015, 8, 20, 18, 14, 48)}},
#  {'_id': ObjectId('573a1393f29313caabcdc814'),
#   'plot': "An American man marries a Serbian immigrant who fears that she will turn into the cat person of her homeland's fables if they are intimate together.",
#   'genres': ['Horror', 'Thriller'],
#   'runtime': 73,
#   'rated': 'APPROVED',
#   'cast': ['Simone Simon', 'Kent Smith', 'Tom Conway', 'Jane Randolph'],
#   'poster': 'https://m.media-amazon.com/images/M/MV5BNzI4YWY0NWQtNWI5YS00MGE4LWE4YTgtMzBmOWIwMzdiYTRiL2ltYWdlL2ltYWdlXkEyXkFqcGdeQXVyNjc1NTYyMjg@._V1_SY1000_SX677_AL_.jpg',
#   'title': 'Cat People',
#   'fullplot': 'Irena Dubrovna, a beautiful and mysterious Serbian-born fashion artist living in New York City, falls in love with and marries average-Joe American Oliver Reed. Their marriage suffers though, as Irena believes that she suffers from an ancient curse- whenever emotionally aroused, she will turn into a panther and kill. Oliver thinks that is absurd and childish, so he sends her to psychiatrist Dr. Judd to cure her. Easier said than done...',
#   'languages': ['English', 'Czech', 'Serbian'],
#   'released': datetime.datetime(1942, 12, 25, 0, 0),
#   'directors': ['Jacques Tourneur'],
#   'writers': ['DeWitt Bodeen'],
#   'awards': {'wins': 1, 'nominations': 2, 'text': '1 win & 2 nominations.'},
#   'lastupdated': '2015-08-21 00:53:54.453000000',
#   'year': 1942,
#   'imdb': {'rating': 7.4, 'votes': 11589, 'id': 34587},
#   'countries': ['USA'],
#   'type': 'movie',
#   'tomatoes': {'viewer': {'rating': 3.6, 'numReviews': 7115},
#    'critic': {'rating': 8.3, 'numReviews': 40, 'meter': 93},
#    'lastUpdated': datetime.datetime(2015, 9, 15, 17, 3, 25),
#    'consensus': 'Influential noir director Jacques Tourneau infused this sexy, moody horror film with some sly commentary about the psychology and the taboos of desire.',
#    'rotten': 3,
#    'production': 'RKO Pictures',
#    'fresh': 37},
#   'num_mflix_comments': 0},
#  {'_id': ObjectId('573a1393f29313caabcdcd9d'),
#   'plot': 'A young Canadian nurse (Betsy) comes to the West Indies to care for Jessica, the wife of a plantation manager (Paul Holland). Jessica seems to be suffering from a kind of mental paralysis ...',
#   'genres': ['Horror'],
#   'runtime': 69,
#   'rated': 'APPROVED',
#   'cast': ['James Ellison', 'Frances Dee', 'Tom Conway', 'Edith Barrett'],
#   'num_mflix_comments': 1,
#   'poster': 'https://m.media-amazon.com/images/M/MV5BZjQzMzliN2YtYTVhNC00Zjc4LThjMmYtMTE0ZGUzMWNmYzJlXkEyXkFqcGdeQXVyMTYxNjkxOQ@@._V1_SY1000_SX677_AL_.jpg',
#   'title': 'I Walked with a Zombie',
#   'fullplot': 'A young Canadian nurse (Betsy) comes to the West Indies to care for Jessica, the wife of a plantation manager (Paul Holland). Jessica seems to be suffering from a kind of mental paralysis as a result of fever. When she falls in love with Paul, Betsy determines to cure Jessica even if she needs to use a voodoo ceremony, to give Paul what she thinks he wants.',
#   'languages': ['English'],
#   'released': datetime.datetime(1943, 4, 30, 0, 0),
#   'directors': ['Jacques Tourneur'],
#   'writers': ['Curt Siodmak (screenplay)',
#    'Ardel Wray (screenplay)',
#    'Inez Wallace (original story)'],
#   'awards': {'wins': 0, 'nominations': 2, 'text': '2 nominations.'},
#   'lastupdated': '2015-08-16 00:16:16.823000000',
#   'year': 1943,
#   'imdb': {'rating': 7.3, 'votes': 6893, 'id': 36027},
#   'countries': ['USA'],
#   'type': 'movie',
#   'tomatoes': {'viewer': {'rating': 3.6, 'numReviews': 4884, 'meter': 75},
#    'dvd': datetime.datetime(2005, 10, 4, 0, 0),
#    'critic': {'rating': 8.1, 'numReviews': 26, 'meter': 92},
#    'lastUpdated': datetime.datetime(2015, 8, 26, 18, 16, 16),
#    'consensus': "Evocative direction by Jacques Tourneur collides with the low-rent production values of exploitateer Val Lewton in I Walked with a Zombie, a sultry sleeper that's simultaneously smarmy, eloquent and fascinating.",
#    'rotten': 2,
#    'production': 'Warner Home Video',
#    'fresh': 24}},
#  {'_id': ObjectId('573a1393f29313caabcdd38c'),
#   'plot': 'A ruthless doctor and his young prize student find themselves continually harassed by their murderous supplier of illegal cadavers.',
#   'genres': ['Horror', 'Thriller'],
#   'runtime': 77,
#   'rated': 'APPROVED',
#   'title': 'The Body Snatcher',
#   'num_mflix_comments': 0,
#   'poster': 'https://m.media-amazon.com/images/M/MV5BNzNmOTE0YTktZGZmYS00N2RhLWI5NTgtYTAyZjZhYWExMmRmXkEyXkFqcGdeQXVyMTQxNzMzNDI@._V1_SY1000_SX677_AL_.jpg',
#   'countries': ['USA'],
#   'fullplot': "In Edinburgh in 1831, Dr. Wolfe MacFarlane runs a medical school where Donald Fettes is a student. Fettes is interested in helping a young girl who has lost the use of her legs. He is certain that MacFarlane's surgical skills could be put to great use but he is reluctant to do so. The good Dr. MacFarlane has a secret that soon becomes all too obvious to young Fettes, who has only recently been promoted as his assistant: he has been paying a local cabbie, John Gray, to supply him with dead bodies for anatomical research. Gray constantly harasses MacFarlane and clearly has a hold over him dating to a famous trial many years before where Gray refused to identify the man for whom he was robbing graves. Fettes isn't aware of any of this but soon realizes exactly how Gray obtains the bodies they use in their anatomy classes.",
#   'languages': ['English'],
#   'cast': ['Boris Karloff', 'Bela Lugosi', 'Henry Daniell', 'Edith Atwater'],
#   'directors': ['Robert Wise'],
#   'writers': ['Robert Louis Stevenson (short story)',
#    'Philip MacDonald (written for the screen by)',
#    'Val Lewton (written for the screen by)'],
#   'awards': {'wins': 0, 'nominations': 3, 'text': '3 nominations.'},
#   'lastupdated': '2015-08-16 01:24:24.840000000',
#   'year': 1945,
#   'imdb': {'rating': 7.4, 'votes': 5509, 'id': 37549},
#   'type': 'movie',
#   'tomatoes': {'viewer': {'rating': 3.5, 'numReviews': 3664, 'meter': 75},
#    'critic': {'rating': 6.8, 'numReviews': 16, 'meter': 81},
#    'lastUpdated': datetime.datetime(2015, 8, 21, 19, 11, 47),
#    'rotten': 3,
#    'production': 'RKO Pictures',
#    'fresh': 13}},
#  {'_id': ObjectId('573a1393f29313caabcdd3ed'),
#   'plot': 'An architect senses impending doom as his half-remembered recurring dream turns into reality. The guests at the country house encourage him to stay as they take turns telling supernatural tales.',
#   'genres': ['Horror'],
#   'runtime': 77,
#   'rated': 'APPROVED',
#   'cast': ['Mervyn Johns', 'Roland Culver', 'Mary Merrall', 'Googie Withers'],
#   'num_mflix_comments': 0,
#   'poster': 'https://m.media-amazon.com/images/M/MV5BYTY2OTJjZjgtMzExMy00MWJlLTg2N2ItM2NhMDQxNTNkNjFhXkEyXkFqcGdeQXVyMjI4MjA5MzA@._V1_SY1000_SX677_AL_.jpg',
#   'title': 'Dead of Night',
#   'fullplot': "Architect Walter Craig, seeking the possibility of some work at a country farmhouse, soon finds himself once again stuck in his recurring nightmare. Dreading the end of the dream that he knows is coming, he must first listen to all the assembled guests' own bizarre tales.",
#   'languages': ['English', 'French'],
#   'released': datetime.datetime(1945, 10, 15, 0, 0),
#   'directors': ['Alberto Cavalcanti',
#    'Charles Crichton',
#    'Basil Dearden',
#    'Robert Hamer'],
#   'writers': ['H.G. Wells (original story)',
#    'E.F. Benson (original story)',
#    'John Baines (original story)',
#    'Angus MacPhail (original story)',
#    'John Baines (screenplay)',
#    'Angus MacPhail (screenplay)',
#    'T.E.B. Clarke (additional dialogue)'],
#   'awards': {'wins': 1, 'nominations': 1, 'text': '1 win & 1 nomination.'},
#   'lastupdated': '2015-09-15 04:38:12.500000000',
#   'year': 1945,
#   'imdb': {'rating': 7.7, 'votes': 7116, 'id': 37635},
#   'countries': ['UK'],
#   'type': 'movie',
#   'tomatoes': {'viewer': {'rating': 4.0, 'numReviews': 3194, 'meter': 88},
#    'dvd': datetime.datetime(2009, 1, 27, 0, 0),
#    'critic': {'rating': 8.0, 'numReviews': 27, 'meter': 96},
#    'lastUpdated': datetime.datetime(2015, 7, 26, 18, 40, 43),
#    'consensus': 'With four accomplished directors contributing, Dead of Night is a classic horror anthology that remains highly influential.',
#    'rotten': 1,
#    'production': 'Universal Pictures',
#    'fresh': 26}},
#  {'_id': ObjectId('573a1393f29313caabcde460'),
#   'plot': "Over-the-hill boxer Bill 'Stoker' Thompson insists he can still win, though his sexy wife Julie pleads with him to quit. But his manager Tiny is so confident he will lose, he takes money ...",
#   'genres': ['Film-Noir', 'Sport'],
#   'runtime': 73,
#   'rated': 'APPROVED',
#   'cast': ['Robert Ryan', 'Audrey Totter', 'George Tobias', 'Alan Baxter'],
#   'num_mflix_comments': 0,
#   'poster': 'https://m.media-amazon.com/images/M/MV5BMjEwNjU3NzE1Nl5BMl5BanBnXkFtZTgwMjQ0MDgyMTE@._V1_SY1000_SX677_AL_.jpg',
#   'title': 'The Set-Up',
#   'fullplot': 'Over-the-hill boxer Bill \'Stoker\' Thompson insists he can still win, though his sexy wife Julie pleads with him to quit. But his manager Tiny is so confident he will lose, he takes money for a "dive" from tough gambler Little Boy...without bothering to tell Stoker. Tension builds as Stoker hopes to "take" Tiger Nelson, unaware of what will happen to him if he does.',
#   'languages': ['English'],
#   'released': datetime.datetime(1949, 4, 2, 0, 0),
#   'directors': ['Robert Wise'],
#   'writers': ['Art Cohn (screenplay)',
#    'Joseph Moncure March (from the poem by)'],
#   'awards': {'wins': 3,
#    'nominations': 1,
#    'text': 'Nominated for 1 BAFTA Film Award. Another 2 wins & 1 nomination.'},
#   'lastupdated': '2015-08-26 00:13:18.837000000',
#   'year': 1949,
#   'imdb': {'rating': 7.8, 'votes': 5309, 'id': 41859},
#   'countries': ['USA'],
#   'type': 'movie',
#   'tomatoes': {'viewer': {'rating': 4.0, 'numReviews': 1692, 'meter': 88},
#    'dvd': datetime.datetime(2004, 7, 6, 0, 0),
#    'critic': {'rating': 5.9, 'numReviews': 7, 'meter': 86},
#    'lastUpdated': datetime.datetime(2015, 7, 26, 18, 33, 52),
#    'rotten': 1,
#    'fresh': 6}}]

# %% [markdown]
# #### Задача 1.5 — **1 балл**

# %% [markdown]
# Модифицируйте запрос из задачи 1.4 таким образом, чтобы осуществить _проекцию_: результатом выборки должен стать список словарей, каждый из которых содержит только два поля: `title` и `year`.
#
# Для справки о проекции см. документацию по методу `find()` в pymongo:
# https://pymongo.readthedocs.io/en/stable/api/pymongo/collection.html#pymongo.collection.Collection.find

# %%
# Ваш код здесь
movies = db.movies
list(movies.find({'$and': [{'genres.0': {'$in': ['Film-Noir', 'Horror']}},
                           {'year': {'$gte': 1940, '$lte': 1949}}]},
                 projection=['title', 'year']
                 ))
# Out:
# [{'_id': ObjectId('573a1393f29313caabcdcdf5'),
#   'title': 'The Leopard Man',
#   'year': 1943},
#  {'_id': ObjectId('573a1393f29313caabcdd6e7'),
#   'title': 'The Chase',
#   'year': 1946},
#  {'_id': ObjectId('573a1393f29313caabcdc814'),
#   'title': 'Cat People',
#   'year': 1942},
#  {'_id': ObjectId('573a1393f29313caabcdcd9d'),
#   'title': 'I Walked with a Zombie',
#   'year': 1943},
#  {'_id': ObjectId('573a1393f29313caabcdd38c'),
#   'title': 'The Body Snatcher',
#   'year': 1945},
#  {'_id': ObjectId('573a1393f29313caabcdd3ed'),
#   'title': 'Dead of Night',
#   'year': 1945},
#  {'_id': ObjectId('573a1393f29313caabcde460'),
#   'title': 'The Set-Up',
#   'year': 1949}]

# %% [markdown]
# ### Упражнение 2. Конвейер агрегации

# %% [markdown]
# #### Задача 2.1 — **3 балла**

# %% [markdown]
# В рамках этой задачи требуется узнать, какие фильмы получили наибольшее число комментариев. Составьте для этого конвейер агрегации с перечисленными ниже этапами. Для удобства рекомендуется воспользоваться приложением Compass.
#
# 1. Сгруппировать документы коллекции `comments` по полю `movie_id` и подсчитать количество комментариев для каждого фильма, записав его в поле `count`.
# 1. Отсортировать получившийся набор данных по убыванию количества комментариев (так чтобы первый документ в этом наборе указывал на фильм с наибольшим количеством комментариев).
# 1. Используя оператор `$lookup`, присоединить коллекцию `movies` (по полю `movie_id`).
# 1. Выполнить проекцию, оставив в наборе данных только три поля: название фильма (`title`), год выпуска (`year`) и количество комментариев (поле `count`, добавленное на первом этапе). Для этого воспользуйтесь оператором `$project`: https://www.mongodb.com/docs/manual/reference/operator/aggregation/project/. Обратите внимание, что данные из коллекции `movies` (`title` и `year`) на этом этапе окажутся внутри массива.
# 1. Применить оператор `$unwind`, чтобы деконструировать этот массив. См. https://www.mongodb.com/docs/manual/reference/operator/aggregation/unwind/. В результате массив должен превратиться в одиночный объект.
# 1. Применить оператор `$addFields`, чтобы добавить поля `title` и `year` на вернхий уровень структуры документа. См. https://www.mongodb.com/docs/manual/reference/operator/aggregation/addFields/.
# 1. Еще раз выполнить проекцию, чтобы удалить поле с массивом.
#
# Ваш алгоритм решения может отличаться от приведенного здесь. Главное — достичь цели: получить плоский набор данных с тремя полями (`count` — количество комментариев, `year` — год выпуска, `title` — название фильма).
#
# Скопируйте полученный конвейер в этот документ в виде кода на Python и выведите его на экран в виде списка словарей.

# %%
# Ваш код здесь
result = list(comments.aggregate(
    [
        {
            '$group': {
                '_id': '$movie_id', 
                'count': {
                    '$sum': 1
                }
            }
        }, {
            '$sort': {
                'count': -1
            }
        }, {
            '$lookup': {
                'from': 'movies', 
                'localField': '_id', 
                'foreignField': '_id', 
                'as': 'movie'
            }
        }, {
            '$project': {
                'movie.title': 1, 
                'movie.year': 1, 
                'count': 1
            }
        }, {
            '$unwind': {
                'path': '$movie'
            }
        }, {
            '$addFields': {
                'title': '$movie.title', 
                'year': '$movie.year'
            }
        }, {
            '$project': {
                'title': 1, 
                'year': 1, 
                'count': 1
            }
        }
    ]
))
result
# Out:
# [{'_id': ObjectId('573a13bff29313caabd5e91e'),
#   'count': 161,
#   'title': 'The Taking of Pelham 1 2 3',
#   'year': 2009},
#  {'_id': ObjectId('573a13b3f29313caabd3b647'),
#   'count': 158,
#   'title': 'Terminator Salvation',
#   'year': 2009},
#  {'_id': ObjectId('573a13a5f29313caabd159a9'),
#   'count': 158,
#   'title': 'About a Boy',
#   'year': 2002},
#  {'_id': ObjectId('573a13abf29313caabd25582'),
#   'count': 158,
#   'title': '50 First Dates',
#   'year': 2004},
#  {'_id': ObjectId('573a13a3f29313caabd0d1e3'),
#   'count': 158,
#   'title': "Ocean's Eleven",
#   'year': 2001},
#  {'_id': ObjectId('573a13bcf29313caabd57db6'),
#   'count': 157,
#   'title': 'Sherlock Holmes',
#   'year': 2009},
#  {'_id': ObjectId('573a139bf29313caabcf3a45'),
#   'count': 157,
#   'title': 'The Mummy',
#   'year': 1999},
#  {'_id': ObjectId('573a13b0f29313caabd3505e'),
#   'count': 155,
#   'title': 'Hellboy II: The Golden Army',
#   'year': 2008},
#  {'_id': ObjectId('573a13acf29313caabd289b3'),
#   'count': 154,
#   'title': 'Anchorman: The Legend of Ron Burgundy',
#   'year': 2004},
#  {'_id': ObjectId('573a13a0f29313caabd05ae1'),
#   'count': 154,
#   'title': 'The Mummy Returns',
#   'year': 2001},
#  {'_id': ObjectId('573a139df29313caabcfb008'),
#   'count': 153,
#   'title': 'American Pie',
#   'year': 1999},
#  {'_id': ObjectId('573a139af29313caabcf0f51'),
#   'count': 153,
#   'title': 'X-Men',
#   'year': 2000},
#  {'_id': ObjectId('573a139af29313caabcf0178'),
#   'count': 153,
#   'title': 'Mission: Impossible',
#   'year': 1996},
#  {'_id': ObjectId('573a13b3f29313caabd3de52'),
#   'count': 153,
#   'title': "Pirates of the Caribbean: At World's End",
#   'year': 2007},
#  {'_id': ObjectId('573a13a9f29313caabd1ea7d'),
#   'count': 153,
#   'title': 'Bruce Almighty',
#   'year': 2003},
#  {'_id': ObjectId('573a1397f29313caabce8413'),
#   'count': 153,
#   'title': 'E.T. the Extra-Terrestrial',
#   'year': 1982},
#  {'_id': ObjectId('573a13b6f29313caabd48454'),
#   'count': 153,
#   'title': 'Wanted',
#   'year': 2008},
#  {'_id': ObjectId('573a1394f29313caabcde63e'),
#   'count': 153,
#   'title': 'Cinderella',
#   'year': 1950},
#  {'_id': ObjectId('573a139ef29313caabcfd114'),
#   'count': 152,
#   'title': 'Gladiator',
#   'year': 2000},
#  {'_id': ObjectId('573a13a7f29313caabd1aa03'),
#   'count': 152,
#   'title': 'The Ring',
#   'year': 2002},
#  {'_id': ObjectId('573a13a6f29313caabd18b78'),
#   'count': 151,
#   'title': 'Meet the Fockers',
#   'year': 2004},
#  {'_id': ObjectId('573a1399f29313caabcee886'),
#   'count': 151,
#   'title': 'The Mask',
#   'year': 1994},
#  {'_id': ObjectId('573a13a2f29313caabd0b8f3'),
#   'count': 151,
#   'title': 'The Matrix Reloaded',
#   'year': 2003},
#  {'_id': ObjectId('573a139af29313caabcf0d8b'),
#   'count': 150,
#   'title': 'Toy Story 2',
#   'year': 1999},
#  {'_id': ObjectId('573a139cf29313caabcf5fde'),
#   'count': 150,
#   'title': 'Big Daddy',
#   'year': 1999},
#  {'_id': ObjectId('573a1399f29313caabcedc5d'),
#   'count': 148,
#   'title': 'Jurassic Park',
#   'year': 1993},
#  {'_id': ObjectId('573a13b5f29313caabd452c3'),
#   'count': 148,
#   'title': 'I Am Legend',
#   'year': 2007},
#  {'_id': ObjectId('573a139af29313caabcef063'),
#   'count': 148,
#   'title': 'Braveheart',
#   'year': 1995},
#  {'_id': ObjectId('573a139ef29313caabcfdb2d'),
#   'count': 147,
#   'title': 'Scary Movie',
#   'year': 2000},
#  {'_id': ObjectId('573a1396f29313caabce5ba0'),
#   'count': 147,
#   'title': 'Jaws',
#   'year': 1975},
#  {'_id': ObjectId('573a13b5f29313caabd42c2f'),
#   'count': 147,
#   'title': 'The Express',
#   'year': 2008},
#  {'_id': ObjectId('573a139af29313caabcf0500'),
#   'count': 146,
#   'title': 'Twister',
#   'year': 1996},
#  {'_id': ObjectId('573a13b7f29313caabd4a269'),
#   'count': 146,
#   'title': 'I Now Pronounce You Chuck & Larry',
#   'year': 2007},
#  {'_id': ObjectId('573a139df29313caabcfaaab'),
#   'count': 145,
#   'title': 'Cast Away',
#   'year': 2000},
#  {'_id': ObjectId('573a13b1f29313caabd36321'),
#   'count': 145,
#   'title': '300',
#   'year': 2006},
#  {'_id': ObjectId('573a1399f29313caabcee578'),
#   'count': 145,
#   'title': 'Dumb & Dumber',
#   'year': 1994},
#  {'_id': ObjectId('573a139af29313caabcf0f16'),
#   'count': 144,
#   'title': 'Saving Private Ryan',
#   'year': 1998},
#  {'_id': ObjectId('573a13aaf29313caabd22abb'),
#   'count': 144,
#   'title': 'School of Rock',
#   'year': 2003},
#  {'_id': ObjectId('573a13baf29313caabd50105'),
#   'count': 144,
#   'title': 'The Last House on the Left',
#   'year': 2009},
#  {'_id': ObjectId('573a13a0f29313caabd02a80'),
#   'count': 144,
#   'title': 'Zoolander',
#   'year': 2001},
#  {'_id': ObjectId('573a13c0f29313caabd60d0d'),
#   'count': 144,
#   'title': 'I Love You, Man',
#   'year': 2009},
#  {'_id': ObjectId('573a1399f29313caabcece7f'),
#   'count': 144,
#   'title': 'Aladdin',
#   'year': 1992},
#  {'_id': ObjectId('573a139af29313caabcf0eae'),
#   'count': 144,
#   'title': 'The Green Mile',
#   'year': 1999},
#  {'_id': ObjectId('573a13b0f29313caabd35746'),
#   'count': 144,
#   'title': 'Spider-Man 3',
#   'year': 2007},
#  {'_id': ObjectId('573a13acf29313caabd29647'),
#   'count': 144,
#   'title': 'King Kong',
#   'year': 2005},
#  {'_id': ObjectId('573a13bff29313caabd5ef57'),
#   'count': 144,
#   'title': 'The Hangover',
#   'year': 2009},
#  {'_id': ObjectId('573a1397f29313caabce8439'),
#   'count': 144,
#   'title': 'Dègkeselyè',
#   'year': 1982},
#  {'_id': ObjectId('573a13b4f29313caabd410a2'),
#   'count': 144,
#   'title': 'The Simpsons Movie',
#   'year': 2007},
#  {'_id': ObjectId('573a13b7f29313caabd4968d'),
#   'count': 144,
#   'title': 'Hostel: Part II',
#   'year': 2007},
#  {'_id': ObjectId('573a13a5f29313caabd133bb'),
#   'count': 143,
#   'title': 'Kill Bill: Vol. 1',
#   'year': 2003},
#  {'_id': ObjectId('573a13a5f29313caabd13a18'),
#   'count': 143,
#   'title': 'Ice Age',
#   'year': 2002},
#  {'_id': ObjectId('573a1399f29313caabcedc5c'),
#   'count': 143,
#   'title': 'The Jungle Creature: Hugo',
#   'year': 1993},
#  {'_id': ObjectId('573a13a7f29313caabd1aa55'),
#   'count': 143,
#   'title': '8 Mile',
#   'year': 2002},
#  {'_id': ObjectId('573a13a7f29313caabd19f82'),
#   'count': 143,
#   'title': 'Harry Potter and the Chamber of Secrets',
#   'year': 2002},
#  {'_id': ObjectId('573a13bef29313caabd5b27a'),
#   'count': 143,
#   'title': 'Up',
#   'year': 2009},
#  {'_id': ObjectId('573a13a5f29313caabd1348f'),
#   'count': 143,
#   'title': 'Rush Hour 2',
#   'year': 2001},
#  {'_id': ObjectId('573a13bff29313caabd5f799'),
#   'count': 142,
#   'title': 'Shutter Island',
#   'year': 2010},
#  {'_id': ObjectId('573a1399f29313caabceeb67'),
#   'count': 142,
#   'title': 'Speed',
#   'year': 1994},
#  {'_id': ObjectId('573a13b8f29313caabd4c3c3'),
#   'count': 142,
#   'title': 'Star Trek',
#   'year': 2009},
#  {'_id': ObjectId('573a13acf29313caabd26d34'),
#   'count': 142,
#   'title': "Ocean's Twelve",
#   'year': 2004},
#  {'_id': ObjectId('573a1398f29313caabceb500'),
#   'count': 142,
#   'title': 'Back to the Future Part II',
#   'year': 1989},
#  {'_id': ObjectId('573a13a3f29313caabd0ebbb'),
#   'count': 141,
#   'title': 'The Princess Diaries',
#   'year': 2001},
#  {'_id': ObjectId('573a13b0f29313caabd35688'),
#   'count': 141,
#   'title': 'Evan Almighty',
#   'year': 2007},
#  {'_id': ObjectId('573a13b3f29313caabd3e31a'),
#   'count': 141,
#   'title': '1408',
#   'year': 2007},
#  {'_id': ObjectId('573a13a9f29313caabd204c1'),
#   'count': 141,
#   'title': 'Freaky Friday',
#   'year': 2003},
#  {'_id': ObjectId('573a13abf29313caabd2403a'),
#   'count': 141,
#   'title': 'Live Free or Die Hard',
#   'year': 2007},
#  {'_id': ObjectId('573a139af29313caabcef02c'),
#   'count': 141,
#   'title': 'Billy Madison',
#   'year': 1995},
#  {'_id': ObjectId('573a139af29313caabcf0f28'),
#   'count': 141,
#   'title': 'Rush Hour',
#   'year': 1998},
#  {'_id': ObjectId('573a13acf29313caabd287dd'),
#   'count': 140,
#   'title': 'Mr. & Mrs. Smith',
#   'year': 2005},
#  {'_id': ObjectId('573a1398f29313caabcebd41'),
#   'count': 140,
#   'title': 'Back to the Future Part III',
#   'year': 1990},
#  {'_id': ObjectId('573a13a4f29313caabd117df'),
#   'count': 140,
#   'title': 'Ghost Rider',
#   'year': 2007},
#  {'_id': ObjectId('573a139af29313caabcf0f68'),
#   'count': 140,
#   'title': 'Men in Black II',
#   'year': 2002},
#  {'_id': ObjectId('573a13b0f29313caabd3408e'),
#   'count': 140,
#   'title': 'War of the Worlds',
#   'year': 2005},
#  {'_id': ObjectId('573a13b3f29313caabd3bfa7'),
#   'count': 140,
#   'title': 'The Bourne Ultimatum',
#   'year': 2007},
#  {'_id': ObjectId('573a13a6f29313caabd18cca'),
#   'count': 140,
#   'title': 'X-Men 2',
#   'year': 2003},
#  {'_id': ObjectId('573a13acf29313caabd26a97'),
#   'count': 140,
#   'title': 'Cheaper by the Dozen',
#   'year': 2003},
#  {'_id': ObjectId('573a139af29313caabceff36'),
#   'count': 139,
#   'title': 'Happy Gilmore',
#   'year': 1996},
#  {'_id': ObjectId('573a139af29313caabceef40'),
#   'count': 139,
#   'title': 'Ace Ventura: When Nature Calls',
#   'year': 1995},
#  {'_id': ObjectId('573a13c1f29313caabd65e75'),
#   'count': 139,
#   'title': 'Saw VI',
#   'year': 2009},
#  {'_id': ObjectId('573a13b2f29313caabd3a6e5'),
#   'count': 139,
#   'title': 'V for Vendetta',
#   'year': 2005},
#  {'_id': ObjectId('573a139af29313caabcf1573'),
#   'count': 139,
#   'title': 'Liar Liar',
#   'year': 1997},
#  {'_id': ObjectId('573a1393f29313caabcdbe7c'),
#   'count': 139,
#   'title': 'The Wizard of Oz',
#   'year': 1939},
#  {'_id': ObjectId('573a13a3f29313caabd0d923'),
#   'count': 139,
#   'title': 'The Matrix Revolutions',
#   'year': 2003},
#  {'_id': ObjectId('573a13a4f29313caabd0f8dc'),
#   'count': 138,
#   'title': 'How to Lose a Guy in 10 Days',
#   'year': 2003},
#  {'_id': ObjectId('573a139bf29313caabcf3d23'),
#   'count': 138,
#   'title': 'The Matrix',
#   'year': 1999},
#  {'_id': ObjectId('573a139ff29313caabd00821'),
#   'count': 138,
#   'title': 'Gone in Sixty Seconds',
#   'year': 2000},
#  {'_id': ObjectId('573a13c6f29313caabd715d3'),
#   'count': 138,
#   'title': 'Men in Black 3',
#   'year': 2012},
#  {'_id': ObjectId('573a13a3f29313caabd0d4c5'),
#   'count': 138,
#   'title': "Harry Potter and the Sorcerer's Stone",
#   'year': 2001},
#  {'_id': ObjectId('573a13b0f29313caabd34419'),
#   'count': 138,
#   'title': 'Sweeney Todd: The Demon Barber of Fleet Street',
#   'year': 2007},
#  {'_id': ObjectId('573a139ef29313caabcfc7b7'),
#   'count': 138,
#   'title': 'How the Grinch Stole Christmas',
#   'year': 2000},
#  {'_id': ObjectId('573a13a3f29313caabd0e7dc'),
#   'count': 138,
#   'title': 'Donnie Darko',
#   'year': 2001},
#  {'_id': ObjectId('573a13bef29313caabd5c293'),
#   'count': 138,
#   'title': 'A Christmas Carol',
#   'year': 2009},
#  {'_id': ObjectId('573a13aef29313caabd2ef9b'),
#   'count': 138,
#   'title': 'Shark Tale',
#   'year': 2004},
#  {'_id': ObjectId('573a13a9f29313caabd1f979'),
#   'count': 137,
#   'title': 'Elf',
#   'year': 2003},
#  {'_id': ObjectId('573a13a4f29313caabd1184b'),
#   'count': 137,
#   'title': 'My Big Fat Greek Wedding',
#   'year': 2002},
#  {'_id': ObjectId('573a13b0f29313caabd33970'),
#   'count': 137,
#   'title': 'The 40-Year-Old Virgin',
#   'year': 2005},
#  {'_id': ObjectId('573a139bf29313caabcf4dd0'),
#   'count': 137,
#   'title': 'Fight Club',
#   'year': 1999},
#  {'_id': ObjectId('573a139af29313caabceffbf'),
#   'count': 137,
#   'title': 'Independence Day',
#   'year': 1996},
#  {'_id': ObjectId('573a139af29313caabcf124d'),
#   'count': 137,
#   'title': 'Star Wars: Episode III - Revenge of the Sith',
#   'year': 2005},
#  {'_id': ObjectId('573a1398f29313caabceace9'),
#   'count': 136,
#   'title': 'Beetlejuice',
#   'year': 1988},
#  {'_id': ObjectId('573a1399f29313caabcee607'),
#   'count': 136,
#   'title': 'Forrest Gump',
#   'year': 1994},
#  {'_id': ObjectId('573a13a7f29313caabd1c099'),
#   'count': 136,
#   'title': 'Harry Potter and the Prisoner of Azkaban',
#   'year': 2004},
#  {'_id': ObjectId('573a13a0f29313caabd04333'),
#   'count': 136,
#   'title': 'Cast Away',
#   'year': 2000},
#  {'_id': ObjectId('573a1399f29313caabcedddc'),
#   'count': 136,
#   'title': 'The Nightmare Before Christmas',
#   'year': 1993},
#  {'_id': ObjectId('573a139af29313caabcf0e10'),
#   'count': 136,
#   'title': 'The Waterboy',
#   'year': 1998},
#  {'_id': ObjectId('573a1397f29313caabce62e7'),
#   'count': 136,
#   'title': 'Rocky',
#   'year': 1976},
#  {'_id': ObjectId('573a13b5f29313caabd42722'),
#   'count': 136,
#   'title': 'The Dark Knight',
#   'year': 2008},
#  {'_id': ObjectId('573a13a4f29313caabd114ac'),
#   'count': 136,
#   'title': 'The Bourne Identity',
#   'year': 2002},
#  {'_id': ObjectId('573a13a6f29313caabd17cde'),
#   'count': 135,
#   'title': 'Signs',
#   'year': 2002},
#  {'_id': ObjectId('573a1398f29313caabceb792'),
#   'count': 135,
#   'title': 'Indiana Jones and the Last Crusade',
#   'year': 1989},
#  {'_id': ObjectId('573a13a0f29313caabd04b3a'),
#   'count': 135,
#   'title': 'Bring It On',
#   'year': 2000},
#  {'_id': ObjectId('573a1398f29313caabceb75d'),
#   'count': 135,
#   'title': 'Honey, I Shrunk the Kids',
#   'year': 1989},
#  {'_id': ObjectId('573a13adf29313caabd2a19b'),
#   'count': 135,
#   'title': 'The Chronicles of Narnia: The Lion, the Witch and the Wardrobe',
#   'year': 2005},
#  {'_id': ObjectId('573a13b4f29313caabd41c04'),
#   'count': 135,
#   'title': 'Push',
#   'year': 2009},
#  {'_id': ObjectId('573a13a1f29313caabd066cb'),
#   'count': 134,
#   'title': 'Miss Congeniality',
#   'year': 2000},
#  {'_id': ObjectId('573a13b9f29313caabd4db57'),
#   'count': 134,
#   'title': 'The Uninvited',
#   'year': 2009},
#  {'_id': ObjectId('573a13a9f29313caabd1ef67'),
#   'count': 134,
#   'title': 'Spider-Man 2',
#   'year': 2004},
#  {'_id': ObjectId('573a13a0f29313caabd0344a'),
#   'count': 134,
#   'title': 'Monsters, Inc.',
#   'year': 2001},
#  {'_id': ObjectId('573a139af29313caabcf0e6c'),
#   'count': 134,
#   'title': 'The Mummy',
#   'year': 1999},
#  {'_id': ObjectId('573a13b0f29313caabd32bdd'),
#   'count': 134,
#   'title': 'Sin City',
#   'year': 2005},
#  {'_id': ObjectId('573a1395f29313caabce3141'),
#   'count': 134,
#   'title': 'The Jungle Book',
#   'year': 1967},
#  {'_id': ObjectId('573a1399f29313caabcec614'),
#   'count': 134,
#   'title': 'Beauty and the Beast',
#   'year': 1991},
#  {'_id': ObjectId('573a13b6f29313caabd46a9f'),
#   'count': 134,
#   'title': 'Fantastic 4: Rise of the Silver Surfer',
#   'year': 2007},
#  {'_id': ObjectId('573a13bef29313caabd5b845'),
#   'count': 134,
#   'title': 'Transformers: Revenge of the Fallen',
#   'year': 2009},
#  {'_id': ObjectId('573a139af29313caabcf0e9d'),
#   'count': 134,
#   'title': 'Fantastic Four',
#   'year': 2005},
#  {'_id': ObjectId('573a13a4f29313caabd0ff64'),
#   'count': 134,
#   'title': 'American Pie 2',
#   'year': 2001},
#  {'_id': ObjectId('573a139ef29313caabcfbd6a'),
#   'count': 133,
#   'title': 'The Lord of the Rings: The Return of the King',
#   'year': 2003},
#  {'_id': ObjectId('573a13a7f29313caabd1aa1f'),
#   'count': 133,
#   'title': 'Shrek 2',
#   'year': 2004},
#  {'_id': ObjectId('573a13bff29313caabd602ef'),
#   'count': 133,
#   'title': 'The Ugly Truth',
#   'year': 2009},
#  {'_id': ObjectId('573a13a2f29313caabd0b257'),
#   'count': 133,
#   'title': 'The Fast and the Furious',
#   'year': 2001},
#  {'_id': ObjectId('573a13b3f29313caabd3d271'),
#   'count': 133,
#   'title': 'Blades of Glory',
#   'year': 2007},
#  {'_id': ObjectId('573a13b3f29313caabd3ebd4'),
#   'count': 132,
#   'title': "The Time Traveler's Wife",
#   'year': 2009},
#  {'_id': ObjectId('573a13b0f29313caabd3573a'),
#   'count': 132,
#   'title': 'Shrek the Third',
#   'year': 2007},
#  {'_id': ObjectId('573a1399f29313caabcee2fa'),
#   'count': 132,
#   'title': 'Ace Ventura: Pet Detective',
#   'year': 1994},
#  {'_id': ObjectId('573a139af29313caabcf0b0a'),
#   'count': 132,
#   'title': 'Men in Black',
#   'year': 1997},
#  {'_id': ObjectId('573a1399f29313caabcedb1f'),
#   'count': 132,
#   'title': 'Free Willy',
#   'year': 1993},
#  {'_id': ObjectId('573a13a9f29313caabd20478'),
#   'count': 132,
#   'title': '2 Fast 2 Furious',
#   'year': 2003},
#  {'_id': ObjectId('573a1399f29313caabcee7fc'),
#   'count': 132,
#   'title': 'The Lion King',
#   'year': 1994},
#  {'_id': ObjectId('573a13a4f29313caabd12b44'),
#   'count': 132,
#   'title': 'Catch Me If You Can',
#   'year': 2002},
#  {'_id': ObjectId('573a139ef29313caabcfc5d8'),
#   'count': 131,
#   'title': 'American Beauty',
#   'year': 1999},
#  {'_id': ObjectId('573a1397f29313caabce68f6'),
#   'count': 131,
#   'title': 'Star Wars: Episode IV - A New Hope',
#   'year': 1977},
#  {'_id': ObjectId('573a13a1f29313caabd066c4'),
#   'count': 131,
#   'title': 'Meet the Parents',
#   'year': 2000},
#  {'_id': ObjectId('573a139af29313caabcef887'),
#   'count': 131,
#   'title': 'Toy Story',
#   'year': 1995},
#  {'_id': ObjectId('573a13bff29313caabd6001f'),
#   'count': 131,
#   'title': 'The Unborn',
#   'year': 2009},
#  {'_id': ObjectId('573a139af29313caabcf224e'),
#   'count': 131,
#   'title': 'Shrek',
#   'year': 2001},
#  {'_id': ObjectId('573a13bff29313caabd5f4a4'),
#   'count': 131,
#   'title': 'Drag Me to Hell',
#   'year': 2009},
#  {'_id': ObjectId('573a139af29313caabcf089f'),
#   'count': 131,
#   'title': 'Doctor Dolittle',
#   'year': 1998},
#  {'_id': ObjectId('573a1396f29313caabce4a9a'),
#   'count': 131,
#   'title': 'The Godfather',
#   'year': 1972},
#  {'_id': ObjectId('573a13a8f29313caabd1ccd1'),
#   'count': 131,
#   'title': 'Shark Tale',
#   'year': 2004},
#  {'_id': ObjectId('573a139ef29313caabcfbdfe'),
#   'count': 131,
#   'title': 'The Sixth Sense',
#   'year': 1999},
#  {'_id': ObjectId('573a139ff29313caabd015b9'),
#   'count': 131,
#   'title': 'The Shawshank Redemption',
#   'year': 1994},
#  {'_id': ObjectId('573a1399f29313caabcec891'),
#   'count': 130,
#   'title': 'Hook',
#   'year': 1991},
#  {'_id': ObjectId('573a1399f29313caabcec24c'),
#   'count': 130,
#   'title': 'Pretty Woman',
#   'year': 1990},
#  {'_id': ObjectId('573a13a9f29313caabd1f93c'),
#   'count': 130,
#   'title': 'The Day After Tomorrow',
#   'year': 2004},
#  {'_id': ObjectId('573a13bef29313caabd5af44'),
#   'count': 130,
#   'title': 'G.I. Joe: The Rise of Cobra',
#   'year': 2009},
#  {'_id': ObjectId('573a1398f29313caabcebfda'),
#   'count': 130,
#   'title': 'Home Alone',
#   'year': 1990},
#  {'_id': ObjectId('573a13b3f29313caabd3b4e1'),
#   'count': 130,
#   'title': 'Ice Age: The Meltdown',
#   'year': 2006},
#  {'_id': ObjectId('573a13c4f29313caabd6cc80'),
#   'count': 129,
#   'title': 'The Dark Knight Rises',
#   'year': 2012},
#  {'_id': ObjectId('573a13b7f29313caabd49ace'),
#   'count': 129,
#   'title': 'Avatar',
#   'year': 2009},
#  {'_id': ObjectId('573a139af29313caabcef021'),
#   'count': 129,
#   'title': 'Bad Boys',
#   'year': 1995},
#  {'_id': ObjectId('573a13a6f29313caabd16847'),
#   'count': 128,
#   'title': 'Mr. Deeds',
#   'year': 2002},
#  {'_id': ObjectId('573a13aaf29313caabd22b04'),
#   'count': 128,
#   'title': 'Troy',
#   'year': 2004},
#  {'_id': ObjectId('573a13b5f29313caabd447fa'),
#   'count': 128,
#   'title': 'Night at the Museum',
#   'year': 2006},
#  {'_id': ObjectId('573a1398f29313caabceb84d'),
#   'count': 128,
#   'title': 'The Little Mermaid',
#   'year': 1989},
#  {'_id': ObjectId('573a139af29313caabcf0a89'),
#   'count': 128,
#   'title': 'Liar Liar',
#   'year': 1997},
#  {'_id': ObjectId('573a139af29313caabcf0d74'),
#   'count': 128,
#   'title': 'Titanic',
#   'year': 1997},
#  {'_id': ObjectId('573a13b6f29313caabd474b1'),
#   'count': 128,
#   'title': 'Stop-Loss',
#   'year': 2008},
#  {'_id': ObjectId('573a13a6f29313caabd16af5'),
#   'count': 128,
#   'title': 'A Walk to Remember',
#   'year': 2002},
#  {'_id': ObjectId('573a13acf29313caabd28635'),
#   'count': 128,
#   'title': 'A Cinderella Story',
#   'year': 2004},
#  {'_id': ObjectId('573a13b1f29313caabd376cf'),
#   'count': 128,
#   'title': 'The Curious Case of Benjamin Button',
#   'year': 2008},
#  {'_id': ObjectId('573a1399f29313caabced54b'),
#   'count': 128,
#   'title': 'Sister Act',
#   'year': 1992},
#  {'_id': ObjectId('573a1395f29313caabce2413'),
#   'count': 128,
#   'title': 'Mary Poppins',
#   'year': 1964},
#  {'_id': ObjectId('573a139af29313caabcf0753'),
#   'count': 128,
#   'title': 'Austin Powers: International Man of Mystery',
#   'year': 1997},
#  {'_id': ObjectId('573a13a0f29313caabd03dcb'),
#   'count': 128,
#   'title': 'X-Men',
#   'year': 2000},
#  {'_id': ObjectId('573a13bdf29313caabd58fd3'),
#   'count': 127,
#   'title': 'Slumdog Millionaire',
#   'year': 2008},
#  {'_id': ObjectId('573a13adf29313caabd29a2b'),
#   'count': 127,
#   'title': 'Inglourious Basterds',
#   'year': 2009},
#  {'_id': ObjectId('573a139ef29313caabcfbd80'),
#   'count': 127,
#   'title': 'The Lord of the Rings: The Two Towers',
#   'year': 2002},
#  {'_id': ObjectId('573a13b8f29313caabd4c7cd'),
#   'count': 127,
#   'title': 'The Incredible Hulk',
#   'year': 2008},
#  {'_id': ObjectId('573a139af29313caabcf0f59'),
#   'count': 127,
#   'title': 'The Wedding Singer',
#   'year': 1998},
#  {'_id': ObjectId('573a13c1f29313caabd63f3d'),
#   'count': 127,
#   'title': 'Funny People',
#   'year': 2009},
#  {'_id': ObjectId('573a13bbf29313caabd5517f'),
#   'count': 127,
#   'title': 'Taken',
#   'year': 2008},
#  {'_id': ObjectId('573a13aaf29313caabd2128b'),
#   'count': 127,
#   'title': 'Pirates of the Caribbean: The Curse of the Black Pearl',
#   'year': 2003},
#  {'_id': ObjectId('573a13a8f29313caabd1c494'),
#   'count': 126,
#   'title': 'Anger Management',
#   'year': 2003},
#  {'_id': ObjectId('573a1397f29313caabce809b'),
#   'count': 126,
#   'title': 'Raiders of the Lost Ark',
#   'year': 1981},
#  {'_id': ObjectId('573a1394f29313caabcdfd61'),
#   'count': 126,
#   'title': 'Lady and the Tramp',
#   'year': 1955},
#  {'_id': ObjectId('573a13a7f29313caabd19f1b'),
#   'count': 126,
#   'title': 'Austin Powers in Goldmember',
#   'year': 2002},
#  {'_id': ObjectId('573a1399f29313caabcedd9e'),
#   'count': 126,
#   'title': 'Mrs. Doubtfire',
#   'year': 1993},
#  {'_id': ObjectId('573a1399f29313caabcecc44'),
#   'count': 125,
#   'title': 'Terminator 2: Judgment Day',
#   'year': 1991},
#  {'_id': ObjectId('573a13a1f29313caabd069c6'),
#   'count': 125,
#   'title': 'Pearl Harbor',
#   'year': 2001},
#  {'_id': ObjectId('573a1398f29313caabceb515'),
#   'count': 125,
#   'title': 'Batman',
#   'year': 1989},
#  {'_id': ObjectId('573a139af29313caabcf0e59'),
#   'count': 124,
#   'title': 'Armageddon',
#   'year': 1998},
#  {'_id': ObjectId('573a139cf29313caabcf6c36'),
#   'count': 124,
#   'title': 'Austin Powers: The Spy Who Shagged Me',
#   'year': 1999},
#  {'_id': ObjectId('573a139ff29313caabd00ea5'),
#   'count': 123,
#   'title': 'Scary Movie',
#   'year': 2000},
#  {'_id': ObjectId('573a13b1f29313caabd36804'),
#   'count': 123,
#   'title': 'Harry Potter and the Half-Blood Prince',
#   'year': 2009},
#  {'_id': ObjectId('573a13b4f29313caabd41aaa'),
#   'count': 123,
#   'title': 'National Treasure: Book of Secrets',
#   'year': 2007},
#  {'_id': ObjectId('573a13a9f29313caabd1f18a'),
#   'count': 123,
#   'title': 'Cars',
#   'year': 2006},
#  {'_id': ObjectId('573a13bef29313caabd5d194'),
#   'count': 122,
#   'title': 'Fighting',
#   'year': 2009},
#  {'_id': ObjectId('573a13bdf29313caabd5a9bd'),
#   'count': 122,
#   'title': 'The Proposal',
#   'year': 2009},
#  {'_id': ObjectId('573a1399f29313caabceeb20'),
#   'count': 122,
#   'title': 'The Shawshank Redemption',
#   'year': 1994},
#  {'_id': ObjectId('573a13b8f29313caabd4d99b'),
#   'count': 122,
#   'title': 'The Stepfather',
#   'year': 2009},
#  {'_id': ObjectId('573a13acf29313caabd27286'),
#   'count': 122,
#   'title': 'The End of a Mystery',
#   'year': 2003},
#  {'_id': ObjectId('573a13b7f29313caabd490b9'),
#   'count': 122,
#   'title': "Ocean's Thirteen",
#   'year': 2007},
#  {'_id': ObjectId('573a1399f29313caabcecbf3'),
#   'count': 121,
#   'title': 'The Silence of the Lambs',
#   'year': 1991},
#  {'_id': ObjectId('573a1399f29313caabceea14'),
#   'count': 121,
#   'title': 'Pulp Fiction',
#   'year': 1994},
#  {'_id': ObjectId('573a13bef29313caabd5ba58'),
#   'count': 121,
#   'title': 'The Invention of Lying',
#   'year': 2009},
#  {'_id': ObjectId('573a13acf29313caabd27283'),
#   'count': 121,
#   'title': 'Madagascar',
#   'year': 2005},
#  {'_id': ObjectId('573a13bef29313caabd5d1e1'),
#   'count': 121,
#   'title': 'Quarantine',
#   'year': 2008},
#  {'_id': ObjectId('573a139af29313caabcf0e73'),
#   'count': 121,
#   'title': "A Bug's Life",
#   'year': 1998},
#  {'_id': ObjectId('573a13b3f29313caabd3ae45'),
#   'count': 121,
#   'title': 'G-Force',
#   'year': 2009},
#  {'_id': ObjectId('573a13a5f29313caabd1333a'),
#   'count': 120,
#   'title': 'Finding Nemo',
#   'year': 2003},
#  {'_id': ObjectId('573a1396f29313caabce482f'),
#   'count': 120,
#   'title': 'Willy Wonka & the Chocolate Factory',
#   'year': 1971},
#  {'_id': ObjectId('573a139cf29313caabcf7448'),
#   'count': 119,
#   'title': '10 Things I Hate About You',
#   'year': 1999},
#  {'_id': ObjectId('573a13aaf29313caabd22342'),
#   'count': 119,
#   'title': 'Harry Potter and the Goblet of Fire',
#   'year': 2005},
#  {'_id': ObjectId('573a13b0f29313caabd348b8'),
#   'count': 119,
#   'title': 'Watchmen',
#   'year': 2009},
#  {'_id': ObjectId('573a13c5f29313caabd7054b'),
#   'count': 119,
#   'title': 'The Hunger Games',
#   'year': 2012},
#  {'_id': ObjectId('573a139af29313caabcef3f1'),
#   'count': 119,
#   'title': 'Jumanji',
#   'year': 1995},
#  {'_id': ObjectId('573a1397f29313caabce6c43'),
#   'count': 119,
#   'title': 'Grease',
#   'year': 1978},
#  {'_id': ObjectId('573a1395f29313caabce1855'),
#   'count': 118,
#   'title': '101 Dalmatians',
#   'year': 1961},
#  {'_id': ObjectId('573a139af29313caabcf1258'),
#   'count': 117,
#   'title': 'Star Wars: Episode II - Attack of the Clones',
#   'year': 2002},
#  {'_id': ObjectId('573a13baf29313caabd506e4'),
#   'count': 117,
#   'title': 'The Avengers',
#   'year': 2012},
#  {'_id': ObjectId('573a13bff29313caabd607e0'),
#   'count': 117,
#   'title': 'Orphan',
#   'year': 2009},
#  {'_id': ObjectId('573a13b2f29313caabd39f21'),
#   'count': 117,
#   'title': 'Saw II',
#   'year': 2005},
#  {'_id': ObjectId('573a13a9f29313caabd1e69d'),
#   'count': 116,
#   'title': 'Love Actually',
#   'year': 2003},
#  {'_id': ObjectId('573a13a8f29313caabd1c7ab'),
#   'count': 116,
#   'title': 'Scary Movie 3',
#   'year': 2003},
#  {'_id': ObjectId('573a1397f29313caabce77d9'),
#   'count': 115,
#   'title': 'Star Wars: Episode V - The Empire Strikes Back',
#   'year': 1980},
#  {'_id': ObjectId('573a13a4f29313caabd10ce0'),
#   'count': 115,
#   'title': 'Sweet Home Alabama',
#   'year': 2002},
#  {'_id': ObjectId('573a1398f29313caabcea621'),
#   'count': 115,
#   'title': 'Dirty Dancing',
#   'year': 1987},
#  {'_id': ObjectId('573a13b3f29313caabd3c93e'),
#   'count': 115,
#   'title': 'Borat: Cultural Learnings of America for Make Benefit Glorious Nation of Kazakhstan',
#   'year': 2006},
#  {'_id': ObjectId('573a13b0f29313caabd342c5'),
#   'count': 115,
#   'title': 'The Departed',
#   'year': 2006},
#  {'_id': ObjectId('573a1398f29313caabcebee5'),
#   'count': 115,
#   'title': 'Edward Scissorhands',
#   'year': 1990},
#  {'_id': ObjectId('573a13a4f29313caabd10f7a'),
#   'count': 115,
#   'title': 'Scary Movie 2',
#   'year': 2001},
#  {'_id': ObjectId('573a13abf29313caabd24a7f'),
#   'count': 115,
#   'title': 'How to Lose a Guy in 10 Days',
#   'year': 2003},
#  {'_id': ObjectId('573a139af29313caabcf0f07'),
#   'count': 114,
#   'title': 'The Lord of the Rings: The Fellowship of the Ring',
#   'year': 2001},
#  {'_id': ObjectId('573a13b2f29313caabd38c3b'),
#   'count': 114,
#   'title': 'Hairspray',
#   'year': 2007},
#  {'_id': ObjectId('573a13b6f29313caabd46b89'),
#   'count': 113,
#   'title': 'Disturbia',
#   'year': 2007},
#  {'_id': ObjectId('573a13bff29313caabd5fcd1'),
#   'count': 111,
#   'title': 'District 9',
#   'year': 2009},
#  {'_id': ObjectId('573a13a0f29313caabd03ac9'),
#   'count': 111,
#   'title': 'Coyote Ugly',
#   'year': 2000},
#  {'_id': ObjectId('573a13b7f29313caabd4a588'),
#   'count': 111,
#   'title': 'American Gangster',
#   'year': 2007},
#  {'_id': ObjectId('573a139df29313caabcfa2fb'),
#   'count': 111,
#   'title': "Charlie's Angels",
#   'year': 2000},
#  {'_id': ObjectId('573a13bcf29313caabd55ab0'),
#   'count': 109,
#   'title': 'The Amazing Spider-Man',
#   'year': 2012},
#  {'_id': ObjectId('573a1399f29313caabced186'),
#   'count': 108,
#   'title': 'Home Alone 2: Lost in New York',
#   'year': 1992},
#  {'_id': ObjectId('573a13b5f29313caabd446ed'),
#   'count': 107,
#   'title': 'Norbit',
#   'year': 2007},
#  {'_id': ObjectId('573a139af29313caabcef122'),
#   'count': 5,
#   'title': 'The Cure',
#   'year': 1995},
#  {'_id': ObjectId('573a1396f29313caabce4c60'),
#   'count': 4,
#   'title': 'Play It Again, Sam',
#   'year': 1972},
#  {'_id': ObjectId('573a13d4f29313caabd99318'),
#   'count': 4,
#   'title': 'Compliance',
#   'year': 2012},
#  {'_id': ObjectId('573a13b2f29313caabd3994f'),
#   'count': 4,
#   'title': 'The Women',
#   'year': 2008},
#  {'_id': ObjectId('573a13bdf29313caabd595be'),
#   'count': 4,
#   'title': 'Splice',
#   'year': 2009},
#  {'_id': ObjectId('573a13abf29313caabd26179'),
#   'count': 4,
#   'title': 'Cowards Bend the Knee or The Blue Hands',
#   'year': 2003},
#  {'_id': ObjectId('573a13b7f29313caabd4ad99'),
#   'count': 4,
#   'title': 'Night Catches Us',
#   'year': 2010},
#  {'_id': ObjectId('573a13aff29313caabd309fa'),
#   'count': 3,
#   'title': 'Syriana',
#   'year': 2005},
#  {'_id': ObjectId('573a1394f29313caabcdfed1'),
#   'count': 3,
#   'title': 'Taira Clan Saga',
#   'year': 1955},
#  {'_id': ObjectId('573a13f5f29313caabde3033'),
#   'count': 3,
#   'title': 'Tired Moonlight',
#   'year': 2015},
#  {'_id': ObjectId('573a1398f29313caabceb5e4'),
#   'count': 3,
#   'title': 'The Cow',
#   'year': 1989},
#  {'_id': ObjectId('573a13b6f29313caabd4684e'),
#   'count': 3,
#   'title': 'Robin-B-Hood',
#   'year': 2006},
#  {'_id': ObjectId('573a139cf29313caabcf5a67'),
#   'count': 3,
#   'title': 'Chile, the Obstinate Memory',
#   'year': 1997},
#  {'_id': ObjectId('573a13a3f29313caabd0db4a'),
#   'count': 3,
#   'title': 'Happenstance',
#   'year': 2000},
#  {'_id': ObjectId('573a13b8f29313caabd4c74a'),
#   'count': 3,
#   'title': 'Epic Movie',
#   'year': 2007},
#  {'_id': ObjectId('573a13a6f29313caabd16453'),
#   'count': 3,
#   'title': 'When Good Ghouls Go Bad',
#   'year': 2001},
#  {'_id': ObjectId('573a1394f29313caabcdf7e9'),
#   'count': 3,
#   'title': 'Chronicle of Poor Lovers',
#   'year': 1954},
#  {'_id': ObjectId('573a1397f29313caabce6478'),
#   'count': 3,
#   'title': 'Roots',
#   'year': 1977},
#  {'_id': ObjectId('573a13c8f29313caabd76d39'),
#   'count': 3,
#   'title': 'The Dark House',
#   'year': 2009},
#  {'_id': ObjectId('573a13edf29313caabdd49ad'),
#   'count': 3,
#   'title': '45 Years',
#   'year': 2015},
#  {'_id': ObjectId('573a1396f29313caabce451a'),
#   'count': 3,
#   'title': 'Duck, You Sucker',
#   'year': 1971},
#  {'_id': ObjectId('573a1398f29313caabceaf10'),
#   'count': 3,
#   'title': 'High Spirits',
#   'year': 1988},
#  {'_id': ObjectId('573a1397f29313caabce6af3'),
#   'count': 3,
#   'title': 'La Cage aux Folles',
#   'year': 1978},
#  {'_id': ObjectId('573a1391f29313caabcd8979'),
#   'count': 3,
#   'title': 'Upstream',
#   'year': 1927},
#  {'_id': ObjectId('573a139af29313caabcf0013'),
#   'count': 3,
#   'title': "Jackie Chan's First Strike",
#   'year': 1996},
#  {'_id': ObjectId('573a13b3f29313caabd3e11b'),
#   'count': 3,
#   'title': 'The Valet',
#   'year': 2006},
#  {'_id': ObjectId('573a13b8f29313caabd4cc55'),
#   'count': 3,
#   'title': 'Palimpsest',
#   'year': 2006},
#  {'_id': ObjectId('573a13b5f29313caabd45038'),
#   'count': 3,
#   'title': 'Ten Skies',
#   'year': 2004},
#  {'_id': ObjectId('573a1395f29313caabce11fc'),
#   'count': 3,
#   'title': 'The Apartment',
#   'year': 1960},
#  {'_id': ObjectId('573a1399f29313caabcec41d'),
#   'count': 3,
#   'title': 'Werner - Beinhart!',
#   'year': 1990},
#  {'_id': ObjectId('573a1398f29313caabceb5c4'),
#   'count': 3,
#   'title': 'Cold Feet',
#   'year': 1989},
#  {'_id': ObjectId('573a13e9f29313caabdcc269'),
#   'count': 3,
#   'title': 'The Saboteurs',
#   'year': 2015},
#  {'_id': ObjectId('573a13cbf29313caabd801b3'),
#   'count': 3,
#   'title': 'Slice',
#   'year': 2009},
#  {'_id': ObjectId('573a13bbf29313caabd5363d'),
#   'count': 3,
#   'title': 'Bride Wars',
#   'year': 2009},
#  {'_id': ObjectId('573a1399f29313caabced18b'),
#   'count': 3,
#   'title': 'Honey I Blew Up the Kid',
#   'year': 1992},
#  {'_id': ObjectId('573a13d3f29313caabd96934'),
#   'count': 3,
#   'title': 'Beauty Day',
#   'year': 2011},
#  {'_id': ObjectId('573a13daf29313caabdac957'),
#   'count': 3,
#   'title': 'Olympus Has Fallen',
#   'year': 2013},
#  {'_id': ObjectId('573a13a4f29313caabd0f823'),
#   'count': 3,
#   'title': '61*',
#   'year': 2001},
#  {'_id': ObjectId('573a13b1f29313caabd36dab'),
#   'count': 3,
#   'title': 'Wah-Wah',
#   'year': 2005},
#  {'_id': ObjectId('573a1395f29313caabce13ac'),
#   'count': 3,
#   'title': 'Macario',
#   'year': 1960},
#  {'_id': ObjectId('573a13c3f29313caabd6af86'),
#   'count': 3,
#   'title': 'Gangster Squad',
#   'year': 2013},
#  {'_id': ObjectId('573a1395f29313caabce13d5'),
#   'count': 3,
#   'title': 'Midnight Lace',
#   'year': 1960},
#  {'_id': ObjectId('573a13bef29313caabd5bca4'),
#   'count': 3,
#   'title': 'La buena nueva',
#   'year': 2008},
#  {'_id': ObjectId('573a13c9f29313caabd7b519'),
#   'count': 3,
#   'title': 'The Unknown Woman',
#   'year': 2011},
#  {'_id': ObjectId('573a1396f29313caabce4752'),
#   'count': 3,
#   'title': 'Silent Running',
#   'year': 1972},
#  {'_id': ObjectId('573a139df29313caabcf9d45'),
#   'count': 3,
#   'title': 'Deterrence',
#   'year': 1999},
#  {'_id': ObjectId('573a1398f29313caabcebd91'),
#   'count': 3,
#   'title': "Betsy's Wedding",
#   'year': 1990},
#  {'_id': ObjectId('573a13b4f29313caabd406a4'),
#   'count': 3,
#   'title': 'Mr. Average',
#   'year': 2006},
#  {'_id': ObjectId('573a1395f29313caabce23db'),
#   'count': 3,
#   'title': 'King & Country',
#   'year': 1964},
#  {'_id': ObjectId('573a13a2f29313caabd0a4e4'),
#   'count': 3,
#   'title': 'Green Dragon',
#   'year': 2001},
#  {'_id': ObjectId('573a13bbf29313caabd538cf'),
#   'count': 3,
#   'title': 'Exte: Hair Extensions',
#   'year': 2007},
#  {'_id': ObjectId('573a1397f29313caabce7e16'),
#   'count': 3,
#   'title': 'Duelul',
#   'year': 1981},
#  {'_id': ObjectId('573a13c6f29313caabd72039'),
#   'count': 3,
#   'title': 'Someone Like You',
#   'year': 2009},
#  {'_id': ObjectId('573a1395f29313caabce196c'),
#   'count': 3,
#   'title': 'A Wife Confesses',
#   'year': 1961},
#  {'_id': ObjectId('573a13dcf29313caabdb130e'),
#   'count': 3,
#   'title': 'Metalhead',
#   'year': 2013},
#  {'_id': ObjectId('573a13c5f29313caabd70ce6'),
#   'count': 3,
#   'title': 'Obitaemyy ostrov. Skhvatka',
#   'year': 2009},
#  {'_id': ObjectId('573a13eef29313caabdd4cd5'),
#   'count': 3,
#   'title': 'Nas: Time Is Illmatic',
#   'year': 2014},
#  {'_id': ObjectId('573a139af29313caabcf0177'),
#   'count': 3,
#   'title': 'Moebius',
#   'year': 1996},
#  {'_id': ObjectId('573a1399f29313caabcecfbb'),
#   'count': 3,
#   'title': 'Christmas in Connecticut',
#   'year': 1992},
#  {'_id': ObjectId('573a13d5f29313caabd9b6e4'),
#   'count': 3,
#   'title': 'Jesse Stone: Benefit of the Doubt',
#   'year': 2012},
#  {'_id': ObjectId('573a13f5f29313caabde445e'),
#   'count': 3,
#   'title': 'The Shaman',
#   'year': 2015},
#  {'_id': ObjectId('573a13cef29313caabd8791b'),
#   'count': 3,
#   'title': 'Metrobranding',
#   'year': 2010},
#  {'_id': ObjectId('573a13d2f29313caabd92945'),
#   'count': 3,
#   'title': 'Overheard 2',
#   'year': 2011},
#  {'_id': ObjectId('573a13c2f29313caabd688cd'),
#   'count': 3,
#   'title': 'Date Night',
#   'year': 2010},
#  {'_id': ObjectId('573a13e0f29313caabdba69b'),
#   'count': 3,
#   'title': 'Monster High: Friday Night Frights',
#   'year': 2013},
#  {'_id': ObjectId('573a1397f29313caabce689a'),
#   'count': 3,
#   'title': 'Scott Joplin',
#   'year': 1977},
#  {'_id': ObjectId('573a1398f29313caabce9c13'),
#   'count': 3,
#   'title': 'Twice in a Lifetime',
#   'year': 1985},
#  {'_id': ObjectId('573a13def29313caabdb66cb'),
#   'count': 3,
#   'title': 'They Are All Dead',
#   'year': 2014},
#  {'_id': ObjectId('573a1396f29313caabce5aca'),
#   'count': 3,
#   'title': 'Euridice BA 2O37',
#   'year': 1975},
#  {'_id': ObjectId('573a13dff29313caabdb7801'),
#   'count': 3,
#   'title': 'Plastic',
#   'year': 2014},
#  {'_id': ObjectId('573a139bf29313caabcf3a3f'),
#   'count': 3,
#   'title': 'Mystery Men',
#   'year': 1999},
#  {'_id': ObjectId('573a1399f29313caabced32b'),
#   'count': 3,
#   'title': 'The Mighty Ducks',
#   'year': 1992},
#  {'_id': ObjectId('573a1397f29313caabce639b'),
#   'count': 3,
#   'title': "That's Entertainment, Part II",
#   'year': 1976},
#  {'_id': ObjectId('573a13d5f29313caabd9a729'),
#   'count': 3,
#   'title': 'Exists',
#   'year': 2014},
#  {'_id': ObjectId('573a13d1f29313caabd904ce'),
#   'count': 3,
#   'title': 'Midnight FM',
#   'year': 2010},
#  {'_id': ObjectId('573a13b4f29313caabd3fdf5'),
#   'count': 3,
#   'title': 'Nacho Libre',
#   'year': 2006},
#  {'_id': ObjectId('573a13aef29313caabd2d5d8'),
#   'count': 3,
#   'title': 'Cube Zero',
#   'year': 2004},
#  {'_id': ObjectId('573a13c6f29313caabd71785'),
#   'count': 3,
#   'title': 'Rabbit è la Berlin',
#   'year': 2009},
#  {'_id': ObjectId('573a1396f29313caabce4ae7'),
#   'count': 3,
#   'title': 'Horror Express',
#   'year': 1972},
#  {'_id': ObjectId('573a13e2f29313caabdbdf6a'),
#   'count': 3,
#   'title': 'Jibeuro ganeun gil',
#   'year': 2013},
#  {'_id': ObjectId('573a1397f29313caabce65df'),
#   'count': 3,
#   'title': 'The House by the Lake',
#   'year': 1976},
#  {'_id': ObjectId('573a1394f29313caabcdfc98'),
#   'count': 3,
#   'title': 'Footsteps in the Fog',
#   'year': 1955},
#  {'_id': ObjectId('573a1399f29313caabcededa'),
#   'count': 3,
#   'title': 'Return of the Living Dead III',
#   'year': 1993},
#  {'_id': ObjectId('573a13baf29313caabd51b4c'),
#   'count': 3,
#   'title': 'City of Men',
#   'year': 2007},
#  {'_id': ObjectId('573a13d3f29313caabd9515c'),
#   'count': 3,
#   'title': 'Lord of Darkness',
#   'year': 2012},
#  {'_id': ObjectId('573a1393f29313caabcde3ca'),
#   'count': 3,
#   'title': "Occupe-toi d'Amèlie..!",
#   'year': 1949},
#  {'_id': ObjectId('573a13c2f29313caabd68ad7'),
#   'count': 3,
#   'title': 'I Am So Proud of You',
#   'year': 2008},
#  {'_id': ObjectId('573a13aef29313caabd2c5db'),
#   'count': 3,
#   'title': 'Kiss Kiss Bang Bang',
#   'year': 2005},
#  {'_id': ObjectId('573a139af29313caabcefa82'),
#   'count': 3,
#   'title': "Dead Man's Walk",
#   'year': 1996},
#  {'_id': ObjectId('573a13b3f29313caabd3ea89'),
#   'count': 3,
#   'title': 'Naming Number Two',
#   'year': 2006},
#  {'_id': ObjectId('573a13a4f29313caabd11d1d'),
#   'count': 3,
#   'title': '3rd World Hero',
#   'year': 2000},
#  {'_id': ObjectId('573a1399f29313caabcee60d'),
#   'count': 3,
#   'title': 'Federal Hill',
#   'year': 1994},
#  {'_id': ObjectId('573a13d0f29313caabd8b9c9'),
#   'count': 3,
#   'title': 'Bringing Ashley Home',
#   'year': 2011},
#  {'_id': ObjectId('573a1399f29313caabcec648'),
#   'count': 3,
#   'title': 'Black Robe',
#   'year': 1991},
#  {'_id': ObjectId('573a13a0f29313caabd02e84'),
#   'count': 3,
#   'title': 'Bartok the Magnificent',
#   'year': 1999},
#  {'_id': ObjectId('573a13e7f29313caabdc83b1'),
#   'count': 3,
#   'title': 'Never Tear Us Apart: The Untold Story of INXS',
#   'year': 2014},
#  {'_id': ObjectId('573a1397f29313caabce8bcb'),
#   'count': 3,
#   'title': 'Max Dugan Returns',
#   'year': 1983},
#  {'_id': ObjectId('573a13a9f29313caabd1f631'),
#   'count': 3,
#   'title': 'The Motorcycle Diaries',
#   'year': 2004},
#  {'_id': ObjectId('573a13c5f29313caabd71322'),
#   'count': 3,
#   'title': 'The Moth Diaries',
#   'year': 2011},
#  {'_id': ObjectId('573a1398f29313caabce9f50'),
#   'count': 3,
#   'title': 'From Beyond',
#   'year': 1986},
#  {'_id': ObjectId('573a13caf29313caabd7df30'),
#   'count': 3,
#   'title': 'Good Neighbors',
#   'year': 2010},
#  {'_id': ObjectId('573a1396f29313caabce58cd'),
#   'count': 3,
#   'title': 'The Promised Land',
#   'year': 1975},
#  {'_id': ObjectId('573a1399f29313caabced948'),
#   'count': 3,
#   'title': 'The Boys of St. Vincent',
#   'year': 1992},
#  {'_id': ObjectId('573a13d0f29313caabd8bd12'),
#   'count': 3,
#   'title': 'Great Migrations',
#   'year': 2010},
#  {'_id': ObjectId('573a139af29313caabcf0042'),
#   'count': 3,
#   'title': 'Drifting Clouds',
#   'year': 1996},
#  {'_id': ObjectId('573a13daf29313caabdad3cc'),
#   'count': 3,
#   'title': 'American Courtesans',
#   'year': 2013},
#  {'_id': ObjectId('573a13b5f29313caabd4328b'),
#   'count': 3,
#   'title': 'Bionicle 3: Web of Shadows',
#   'year': 2005},
#  {'_id': ObjectId('573a13a0f29313caabd03c8e'),
#   'count': 3,
#   'title': 'The Rising Place',
#   'year': 2001},
#  {'_id': ObjectId('573a13e7f29313caabdc6de0'),
#   'count': 3,
#   'title': 'Misconception',
#   'year': 2014},
#  {'_id': ObjectId('573a13c9f29313caabd7ba99'),
#   'count': 3,
#   'title': 'Without Men',
#   'year': 2011},
#  {'_id': ObjectId('573a13adf29313caabd2a096'),
#   'count': 3,
#   'title': 'Black Cloud',
#   'year': 2004},
#  {'_id': ObjectId('573a139af29313caabcf07c5'),
#   'count': 3,
#   'title': 'The Boxer',
#   'year': 1997},
#  {'_id': ObjectId('573a1395f29313caabce26c7'),
#   'count': 3,
#   'title': 'The Cincinnati Kid',
#   'year': 1965},
#  {'_id': ObjectId('573a13f5f29313caabde2e85'),
#   'count': 3,
#   'title': '3 1/2 Minutes, Ten Bullets',
#   'year': 2015},
#  {'_id': ObjectId('573a13d0f29313caabd8c227'),
#   'count': 3,
#   'title': 'The Dark Side of Chocolate',
#   'year': 2010},
#  {'_id': ObjectId('573a13cef29313caabd887e0'),
#   'count': 3,
#   'title': 'Pink Saris',
#   'year': 2010},
#  {'_id': ObjectId('573a13bff29313caabd5ed8a'),
#   'count': 3,
#   'title': 'Batman: Gotham Knight',
#   'year': 2008},
#  {'_id': ObjectId('573a13ddf29313caabdb32e2'),
#   'count': 3,
#   'title': 'Stand Clear of the Closing Doors',
#   'year': 2013},
#  {'_id': ObjectId('573a13bbf29313caabd5315e'),
#   'count': 3,
#   'title': 'Cairo Time',
#   'year': 2009},
#  {'_id': ObjectId('573a13a4f29313caabd0f593'),
#   'count': 3,
#   'title': 'Bonhoeffer: Agent of Grace',
#   'year': 2000},
#  {'_id': ObjectId('573a13aef29313caabd2dc92'),
#   'count': 3,
#   'title': 'Proteus',
#   'year': 2003},
#  {'_id': ObjectId('573a139af29313caabcf0738'),
#   'count': 3,
#   'title': 'Amistad',
#   'year': 1997},
#  {'_id': ObjectId('573a1396f29313caabce3627'),
#   'count': 3,
#   'title': "Je t'aime je t'aime",
#   'year': 1968},
#  {'_id': ObjectId('573a13bff29313caabd60471'),
#   'count': 3,
#   'title': 'Peter and Vandy',
#   'year': 2009},
#  {'_id': ObjectId('573a139df29313caabcfb8b9'),
#   'count': 3,
#   'title': 'A True Mob Story',
#   'year': 1998},
#  {'_id': ObjectId('573a13b4f29313caabd3f5fc'),
#   'count': 3,
#   'title': 'Comeback Season',
#   'year': 2006},
#  {'_id': ObjectId('573a139af29313caabcf07ed'),
#   'count': 3,
#   'title': 'The House',
#   'year': 1997},
#  {'_id': ObjectId('573a13abf29313caabd25f95'),
#   'count': 3,
#   'title': 'Hitler: The Rise of Evil',
#   'year': 2003},
#  {'_id': ObjectId('573a13a0f29313caabd05a65'),
#   'count': 3,
#   'title': "Everybody's Famous!",
#   'year': 2000},
#  {'_id': ObjectId('573a139df29313caabcfada8'),
#   'count': 3,
#   'title': 'Jurassic Park III',
#   'year': 2001},
#  {'_id': ObjectId('573a13adf29313caabd29bea'),
#   'count': 3,
#   'title': 'The Terminal',
#   'year': 2004},
#  {'_id': ObjectId('573a1395f29313caabce1faa'),
#   'count': 3,
#   'title': 'Yesterday, Today and Tomorrow',
#   'year': 1963},
#  {'_id': ObjectId('573a13d2f29313caabd9128d'),
#   'count': 3,
#   'title': 'Bleak Night',
#   'year': 2010},
#  {'_id': ObjectId('573a1399f29313caabcee6b2'),
#   'count': 3,
#   'title': 'Pom Poko',
#   'year': 1994},
#  {'_id': ObjectId('573a13c8f29313caabd780f8'),
#   'count': 3,
#   'title': "The King's Speech",
#   'year': 2010},
#  {'_id': ObjectId('573a13aff29313caabd30012'),
#   'count': 3,
#   'title': 'Dig!',
#   'year': 2004},
#  {'_id': ObjectId('573a139af29313caabcefeba'),
#   'count': 3,
#   'title': 'Forgotten Silver',
#   'year': 1995},
#  {'_id': ObjectId('573a139af29313caabcef485'),
#   'count': 3,
#   'title': "Lilian's Story",
#   'year': 1996},
#  {'_id': ObjectId('573a13d0f29313caabd8d988'),
#   'count': 3,
#   'title': 'Inherent Vice',
#   'year': 2014},
#  {'_id': ObjectId('573a13ccf29313caabd81793'),
#   'count': 3,
#   'title': 'Cesar Chavez',
#   'year': 2014},
#  {'_id': ObjectId('573a13d9f29313caabda9a6f'),
#   'count': 3,
#   'title': 'SAGA: Curse of the Shadow',
#   'year': 2013},
#  {'_id': ObjectId('573a139af29313caabcf1d11'),
#   'count': 3,
#   'title': 'Return to Paradise',
#   'year': 1998},
#  {'_id': ObjectId('573a1395f29313caabce18dc'),
#   'count': 3,
#   'title': 'The Roman Spring of Mrs. Stone',
#   'year': 1961},
#  {'_id': ObjectId('573a139af29313caabcf0d02'),
#   'count': 2,
#   'title': 'Speed 2: Cruise Control',
#   'year': 1997},
#  {'_id': ObjectId('573a13bbf29313caabd53718'),
#   'count': 2,
#   'title': 'The Crimson Wing: Mystery of the Flamingos',
#   'year': 2008},
#  {'_id': ObjectId('573a13f3f29313caabdde810'),
#   'count': 2,
#   'title': 'Call Me Lucky',
#   'year': 2015},
#  {'_id': ObjectId('573a13caf29313caabd7d233'),
#   'count': 2,
#   'title': 'Savage',
#   'year': 2011},
#  {'_id': ObjectId('573a13d6f29313caabd9f296'),
#   'count': 2,
#   'title': 'Lad: A Yorkshire Story',
#   'year': 2013},
#  {'_id': ObjectId('573a13acf29313caabd27651'),
#   'count': 2,
#   'title': 'Cinderella Man',
#   'year': 2005},
#  {'_id': ObjectId('573a13a1f29313caabd074e2'),
#   'count': 2,
#   'title': 'Kiss Me in the Rain',
#   'year': 1999},
#  {'_id': ObjectId('573a13c3f29313caabd69d6d'),
#   'count': 2,
#   'title': 'Kung Fu Panda 2',
#   'year': 2011},
#  {'_id': ObjectId('573a1399f29313caabced446'),
#   'count': 2,
#   'title': 'The Player',
#   'year': 1992},
#  {'_id': ObjectId('573a13eaf29313caabdcf071'),
#   'count': 2,
#   'title': 'Polycarp',
#   'year': 2015},
#  {'_id': ObjectId('573a13d2f29313caabd92ba9'),
#   'count': 2,
#   'title': 'Percy Jackson: Sea of Monsters',
#   'year': 2013},
#  {'_id': ObjectId('573a13a3f29313caabd0cd6d'),
#   'count': 2,
#   'title': 'Marine Battleground',
#   'year': 1963},
#  {'_id': ObjectId('573a13a5f29313caabd144cd'),
#   'count': 2,
#   'title': 'R.S.V.P.',
#   'year': 2002},
#  {'_id': ObjectId('573a1398f29313caabce9764'),
#   'count': 2,
#   'title': 'Death of a Salesman',
#   'year': 1985},
#  {'_id': ObjectId('573a1398f29313caabceaf2e'),
#   'count': 2,
#   'title': 'The House on Carroll Street',
#   'year': 1988},
#  {'_id': ObjectId('573a1398f29313caabcebbe0'),
#   'count': 2,
#   'title': 'Sweetie',
#   'year': 1989},
#  {'_id': ObjectId('573a13dff29313caabdb745d'),
#   'count': 2,
#   'title': 'Little Hope Was Arson',
#   'year': 2013},
#  {'_id': ObjectId('573a13abf29313caabd240a5'),
#   'count': 2,
#   'title': 'Head in the Clouds',
#   'year': 2004},
#  {'_id': ObjectId('573a13e7f29313caabdc7aed'),
#   'count': 2,
#   'title': 'Houdini',
#   'year': 2014},
#  {'_id': ObjectId('573a1394f29313caabcdf633'),
#   'count': 2,
#   'title': 'The Adultress',
#   'year': 1953},
#  {'_id': ObjectId('573a13a7f29313caabd1a65b'),
#   'count': 2,
#   'title': 'Ghosts of the Abyss',
#   'year': 2003},
#  {'_id': ObjectId('573a13a8f29313caabd1e462'),
#   'count': 2,
#   'title': 'Two Weeks Notice',
#   'year': 2002},
#  {'_id': ObjectId('573a139ff29313caabd0123b'),
#   'count': 2,
#   'title': 'Miss Julie',
#   'year': 1999},
#  {'_id': ObjectId('573a13b6f29313caabd47821'),
#   'count': 2,
#   'title': 'Sarkar Raj',
#   'year': 2008},
#  {'_id': ObjectId('573a1393f29313caabcdd1f5'),
#   'count': 2,
#   'title': 'National Velvet',
#   'year': 1944},
#  {'_id': ObjectId('573a13c8f29313caabd78625'),
#   'count': 2,
#   'title': "We Don't Care About Music Anyway",
#   'year': 2009},
#  {'_id': ObjectId('573a13e9f29313caabdcc6c6'),
#   'count': 2,
#   'title': 'Equals',
#   'year': 2015},
#  {'_id': ObjectId('573a13c5f29313caabd70843'),
#   'count': 2,
#   'title': 'The Wild and Wonderful Whites of West Virginia',
#   'year': 2009},
#  {'_id': ObjectId('573a1397f29313caabce7d75'),
#   'count': 2,
#   'title': 'Cattle Annie and Little Britches',
#   'year': 1981},
#  {'_id': ObjectId('573a13e4f29313caabdc0f2c'),
#   'count': 2,
#   'title': '20,000 Days on Earth',
#   'year': 2014},
#  {'_id': ObjectId('573a13e0f29313caabdbb5c9'),
#   'count': 2,
#   'title': 'Locke',
#   'year': 2013},
#  {'_id': ObjectId('573a13dbf29313caabdb0047'),
#   'count': 2,
#   'title': 'All the Wilderness',
#   'year': 2014},
#  {'_id': ObjectId('573a13bef29313caabd5ce3b'),
#   'count': 2,
#   'title': 'Faintheart',
#   'year': 2008},
#  {'_id': ObjectId('573a1399f29313caabceed0d'),
#   'count': 2,
#   'title': 'What Happened Was...',
#   'year': 1994},
#  {'_id': ObjectId('573a13c3f29313caabd69dad'),
#   'count': 2,
#   'title': 'Yogi Bear',
#   'year': 2010},
#  {'_id': ObjectId('573a13a6f29313caabd1842e'),
#   'count': 2,
#   'title': 'The Medallion',
#   'year': 2003},
#  {'_id': ObjectId('573a1397f29313caabce65f1'),
#   'count': 2,
#   'title': 'Boys',
#   'year': 1977},
#  {'_id': ObjectId('573a13d2f29313caabd93221'),
#   'count': 2,
#   'title': 'To Rome with Love',
#   'year': 2012},
#  {'_id': ObjectId('573a13caf29313caabd7e05b'),
#   'count': 2,
#   'title': 'Dear Guest, When Will You Leave?',
#   'year': 2010},
#  {'_id': ObjectId('573a13d6f29313caabda06c6'),
#   'count': 2,
#   'title': 'The Returned',
#   'year': 2013},
#  {'_id': ObjectId('573a1397f29313caabce7261'),
#   'count': 2,
#   'title': 'The Great Santini',
#   'year': 1979},
#  {'_id': ObjectId('573a13b7f29313caabd496e2'),
#   'count': 2,
#   'title': 'The Professor and His Beloved Equation',
#   'year': 2006},
#  {'_id': ObjectId('573a13f7f29313caabde697c'),
#   'count': 2,
#   'title': 'The Pearl Button',
#   'year': 2015},
#  {'_id': ObjectId('573a13e3f29313caabdc02f9'),
#   'count': 2,
#   'title': "Patrick's Day",
#   'year': 2014},
#  {'_id': ObjectId('573a13e7f29313caabdc8c6e'),
#   'count': 2,
#   'title': 'Pride',
#   'year': 2014},
#  {'_id': ObjectId('573a13d8f29313caabda6711'),
#   'count': 2,
#   'title': 'Teenage',
#   'year': 2013},
#  {'_id': ObjectId('573a1396f29313caabce4b04'),
#   'count': 2,
#   'title': 'Images',
#   'year': 1972},
#  {'_id': ObjectId('573a13d5f29313caabd9cd69'),
#   'count': 2,
#   'title': 'Century of Birthing',
#   'year': 2011},
#  {'_id': ObjectId('573a13d5f29313caabd9ccc8'),
#   'count': 2,
# ...
#  {'_id': ObjectId('573a13d4f29313caabd9867b'),
#   'count': 2,
#   'title': 'Girl Fight',
#   'year': 2011},
#  {'_id': ObjectId('573a1394f29313caabcdfd4c'),
#   'count': 2,
#   'title': 'The Kentuckian',
#   'year': 1955},
#  {'_id': ObjectId('573a13b4f29313caabd41057'),
#   'count': 2,
#   'title': 'Pierrepoint: The Last Hangman',
#   'year': 2005},
#  {'_id': ObjectId('573a1394f29313caabce0067'),
#   'count': 2,
#   'title': 'The Catered Affair',
#   'year': 1956},
#  {'_id': ObjectId('573a13a8f29313caabd1e3d0'),
#   'count': 2,
#   'title': 'Funeral March',
#   'year': 2001},
#  {'_id': ObjectId('573a13c0f29313caabd6301f'),
#   'count': 2,
#   'title': 'Kacheli',
#   'year': 2008},
#  {'_id': ObjectId('573a1398f29313caabceace3'),
#   'count': 2,
#   'title': 'Beaches',
#   'year': 1988},
#  {'_id': ObjectId('573a1397f29313caabce8682'),
#   'count': 2,
#   'title': "Porky's",
#   'year': 1981},
#  {'_id': ObjectId('573a139af29313caabcefc19'),
#   'count': 2,
#   'title': 'Beavis and Butt-Head Do America',
#   'year': 1996},
#  {'_id': ObjectId('573a13dcf29313caabdb17e2'),
#   'count': 2,
#   'title': 'Approaching the Elephant',
#   'year': 2014},
#  {'_id': ObjectId('573a13aff29313caabd31977'),
#   'count': 2,
#   'title': 'Hardcore',
#   'year': 2004},
#  {'_id': ObjectId('573a13cdf29313caabd85b0a'),
#   'count': 2,
#   'title': 'Girl Walks Into a Bar',
#   'year': 2011},
#  {'_id': ObjectId('573a13abf29313caabd26423'),
#   'count': 2,
#   'title': "Avellaneda's Moon",
#   'year': 2004},
#  {'_id': ObjectId('573a139af29313caabcf0516'),
#   'count': 2,
#   'title': 'Up Close & Personal',
#   'year': 1996},
#  {'_id': ObjectId('573a13c7f29313caabd74de2'),
#   'count': 2,
#   'title': 'Goon',
#   'year': 2011},
#  {'_id': ObjectId('573a13e9f29313caabdcd0d3'),
#   'count': 2,
#   'title': 'Youth',
#   'year': 2015},
#  {'_id': ObjectId('573a13daf29313caabdab9e6'),
#   'count': 2,
#   'title': 'Sleeping with the Fishes',
#   'year': 2013},
#  {'_id': ObjectId('573a13a0f29313caabd03a75'),
#   'count': 2,
#   'title': 'The Bank Job',
#   'year': 2008},
#  {'_id': ObjectId('573a13bff29313caabd5fae8'),
#   'count': 2,
#   'title': 'Precious',
#   'year': 2009},
#  {'_id': ObjectId('573a1392f29313caabcdad3c'),
#   'count': 2,
#   'title': 'The Green Pastures',
#   'year': 1936},
#  {'_id': ObjectId('573a1395f29313caabce2411'),
#   'count': 2,
#   'title': 'Marnie',
#   'year': 1964},
#  {'_id': ObjectId('573a1399f29313caabcec8fe'),
#   'count': 2,
#   'title': 'Kafka',
#   'year': 1991},
#  {'_id': ObjectId('573a13c4f29313caabd6d777'),
#   'count': 2,
#   'title': "I'm Still Here",
#   'year': 2010},
#  {'_id': ObjectId('573a13a9f29313caabd209d9'),
#   'count': 2,
#   'title': 'The Settlement',
#   'year': 2002},
#  {'_id': ObjectId('573a13bbf29313caabd53651'),
#   'count': 2,
#   'title': 'Eye in the Sky',
#   'year': 2007},
#  {'_id': ObjectId('573a13c2f29313caabd68b3c'),
#   'count': 2,
#   'title': 'Sorry for the Disturbance',
#   'year': 2008},
#  {'_id': ObjectId('573a13caf29313caabd7e7f8'),
#   'count': 2,
#   'title': 'Steam of Life',
#   'year': 2010},
#  {'_id': ObjectId('573a13cdf29313caabd84906'),
#   'count': 2,
#   'title': 'The Delay',
#   'year': 2012},
#  {'_id': ObjectId('573a1397f29313caabce7db1'),
#   'count': 2,
#   'title': "Cutter's Way",
#   'year': 1981},
#  {'_id': ObjectId('573a13a8f29313caabd1c8bb'),
#   'count': 2,
#   'title': 'Transistor Love Story',
#   'year': 2001},
#  {'_id': ObjectId('573a13baf29313caabd5021a'),
#   'count': 2,
#   'title': 'Son of Rambow',
#   'year': 2007},
#  {'_id': ObjectId('573a13abf29313caabd26200'),
#   'count': 2,
#   'title': 'Eloise at the Plaza',
#   'year': 2003},
#  {'_id': ObjectId('573a1398f29313caabce9022'),
#   'count': 2,
#   'title': 'City Heat',
#   'year': 1984},
#  {'_id': ObjectId('573a1395f29313caabce1f3b'),
#   'count': 2,
#   'title': '40 Pounds of Trouble',
#   'year': 1962},
#  {'_id': ObjectId('573a139df29313caabcfa665'),
#   'count': 2,
#   'title': 'What Lies Beneath',
#   'year': 2000},
#  {'_id': ObjectId('573a1398f29313caabcea595'),
#   'count': 2,
#   'title': 'China Girl',
#   'year': 1987},
#  {'_id': ObjectId('573a139ef29313caabcfee71'),
#   'count': 2,
#   'title': 'Two Deaths',
#   'year': 1995},
#  {'_id': ObjectId('573a13c2f29313caabd66795'),
#   'count': 2,
#   'title': 'Looking for Eric',
#   'year': 2009},
#  {'_id': ObjectId('573a13b5f29313caabd452c6'),
#   'count': 2,
#   'title': 'Interview',
#   'year': 2007},
#  {'_id': ObjectId('573a13b6f29313caabd46726'),
#   'count': 2,
#   'title': 'The Education of Fairies',
#   'year': 2006},
#  {'_id': ObjectId('573a13a9f29313caabd1fac0'),
#   'count': 2,
#   'title': 'A House Built on Water',
#   'year': 2003},
#  {'_id': ObjectId('573a13dff29313caabdb7626'),
#   'count': 2,
#   'title': 'The Infinite Man',
#   'year': 2014},
#  {'_id': ObjectId('573a13a5f29313caabd13b4b'),
#   'count': 2,
#   'title': 'The Time Machine',
#   'year': 2002},
#  {'_id': ObjectId('573a13d7f29313caabda4e3c'),
#   'count': 2,
#   'title': 'Bad Words',
#   'year': 2013},
#  {'_id': ObjectId('573a1397f29313caabce6e3a'),
#   'count': 2,
#   'title': 'Remember My Name',
#   'year': 1978},
#  {'_id': ObjectId('573a13aff29313caabd305d3'),
#   'count': 2,
#   'title': 'Primer',
#   'year': 2004},
#  {'_id': ObjectId('573a13bcf29313caabd55c86'),
#   'count': 2,
#   'title': "Tuya's Marriage",
#   'year': 2006},
#  {'_id': ObjectId('573a1396f29313caabce5a73'),
#   'count': 2,
#   'title': 'Dog Day Afternoon',
#   'year': 1975},
#  {'_id': ObjectId('573a13aef29313caabd2c842'),
#   'count': 2,
#   'title': 'Nomad: The Warrior',
#   'year': 2005},
#  {'_id': ObjectId('573a1396f29313caabce34ab'),
#   'count': 2,
#   'title': 'The Brotherhood',
#   'year': 1968},
#  {'_id': ObjectId('573a13bbf29313caabd52c70'),
#   'count': 2,
#   'title': 'Finding Amanda',
#   'year': 2008},
#  {'_id': ObjectId('573a13a0f29313caabd0555d'),
#   'count': 2,
#   'title': 'Rated X',
#   'year': 2000},
#  {'_id': ObjectId('573a13e3f29313caabdc08ef'),
#   'count': 2,
#   'title': "Thou Gild'st the Even",
#   'year': 2013},
#  {'_id': ObjectId('573a1393f29313caabcdd74c'),
#   'count': 2,
#   'title': 'Enamorada',
#   'year': 1946},
#  {'_id': ObjectId('573a13d2f29313caabd92b3f'),
#   'count': 2,
#   'title': 'The Union',
#   'year': 2011},
#  {'_id': ObjectId('573a13d0f29313caabd8b0a1'),
#   'count': 2,
#   'title': 'The Giants',
#   'year': 2011},
#  {'_id': ObjectId('573a139ef29313caabcfeaa1'),
#   'count': 2,
#   'title': 'Hitman Hart: Wrestling with Shadows',
#   'year': 1998},
#  {'_id': ObjectId('573a13c4f29313caabd6bcc0'),
#   'count': 2,
#   'title': 'Raavan',
#   'year': 2010},
#  {'_id': ObjectId('573a13adf29313caabd2aabd'),
#   'count': 2,
#   'title': 'Anacondas: The Hunt for the Blood Orchid',
#   'year': 2004},
#  {'_id': ObjectId('573a139af29313caabcef632'),
#   'count': 2,
#   'title': 'Panther',
#   'year': 1995},
#  {'_id': ObjectId('573a13b8f29313caabd4b407'),
#   'count': 2,
#   'title': 'The Signal',
#   'year': 2007},
#  {'_id': ObjectId('573a139df29313caabcfac5a'),
#   'count': 2,
#   'title': 'A Slipping-Down Life',
#   'year': 1999},
#  {'_id': ObjectId('573a13a6f29313caabd16546'),
#   'count': 2,
#   'title': 'Sorority Boys',
#   'year': 2002},
#  {'_id': ObjectId('573a13c1f29313caabd65230'),
#   'count': 2,
#   'title': 'Motherhood',
#   'year': 2009},
#  {'_id': ObjectId('573a13ccf29313caabd826b2'),
#   'count': 2,
#   'title': 'Jitters',
#   'year': 2010},
#  {'_id': ObjectId('573a13b5f29313caabd43490'),
#   'count': 2,
#   'title': 'Local Color',
#   'year': 2006},
#  {'_id': ObjectId('573a13a3f29313caabd0e3de'),
#   'count': 2,
#   'title': "Varian's War",
#   'year': 2001},
#  {'_id': ObjectId('573a13d9f29313caabdaa111'),
#   'count': 2,
#   'title': 'Villegas',
#   'year': 2012},
#  {'_id': ObjectId('573a13a1f29313caabd08d89'),
#   'count': 2,
#   'title': 'Brother',
#   'year': 2000},
#  {'_id': ObjectId('573a13c8f29313caabd76dc4'),
#   'count': 2,
#   'title': 'The Raven',
#   'year': 2012},
#  {'_id': ObjectId('573a13cdf29313caabd84f57'),
#   'count': 2,
#   'title': 'Familiar Grounds',
#   'year': 2011},
#  {'_id': ObjectId('573a13d5f29313caabd9cc57'),
#   'count': 2,
#   'title': 'Justice League: Doom',
#   'year': 2012},
#  {'_id': ObjectId('573a1395f29313caabce1d9c'),
#   'count': 2,
#   'title': 'Two for the Seesaw',
#   'year': 1962},
#  {'_id': ObjectId('573a1397f29313caabce8739'),
#   'count': 2,
#   'title': 'Six Weeks',
#   'year': 1982},
#  {'_id': ObjectId('573a13aef29313caabd2da15'),
#   'count': 2,
#   'title': 'Star Runner',
#   'year': 2003},
#  {'_id': ObjectId('573a13cff29313caabd89ec7'),
#   'count': 2,
#   'title': 'Motorway',
#   'year': 2012},
#  {'_id': ObjectId('573a13d9f29313caabda885a'),
#   'count': 2,
#   'title': 'Sand Castles',
#   'year': 2014},
#  {'_id': ObjectId('573a13a4f29313caabd103a6'),
#   'count': 2,
#   'title': 'The King of the Street Cleaners',
#   'year': 1977},
#  {'_id': ObjectId('573a13ccf29313caabd8326e'),
#   'count': 2,
#   'title': 'The Names of Love',
#   'year': 2010},
#  {'_id': ObjectId('573a13cef29313caabd86173'),
#   'count': 2,
#   'title': 'The Awakening',
#   'year': 2011},
#  {'_id': ObjectId('573a13a1f29313caabd06ae5'),
#   'count': 2,
#   'title': 'The Amati Girls',
#   'year': 2000},
#  {'_id': ObjectId('573a13a3f29313caabd0d9b4'),
#   'count': 2,
#   'title': 'Come Undone',
#   'year': 2000},
#  {'_id': ObjectId('573a13b0f29313caabd332ac'),
#   'count': 2,
#   'title': 'Utomlyonnye solntsem 2: Predstoyanie',
#   'year': 2010},
#  {'_id': ObjectId('573a13bff29313caabd5fef4'),
#   'count': 2,
#   'title': 'The Land Before Time XIII: The Wisdom of Friends',
#   'year': 2007},
#  {'_id': ObjectId('573a139af29313caabcf07a2'),
#   'count': 2,
#   'title': 'Blackrock',
#   'year': 1997},
#  {'_id': ObjectId('573a13c3f29313caabd6952e'),
#   'count': 2,
#   'title': 'Oye Lucky! Lucky Oye!',
#   'year': 2008},
#  {'_id': ObjectId('573a13c2f29313caabd67216'),
#   'count': 2,
#   'title': 'Snakes and Earrings',
#   'year': 2008},
#  {'_id': ObjectId('573a13acf29313caabd286c6'),
#   'count': 2,
#   'title': 'The Forgotten',
#   'year': 2004},
#  {'_id': ObjectId('573a139df29313caabcf8e0d'),
#   'count': 2,
#   'title': 'Happiness',
#   'year': 1998},
#  {'_id': ObjectId('573a13e8f29313caabdca45b'),
#   'count': 2,
#   'title': 'Dreamcatcher',
#   'year': 2015},
#  {'_id': ObjectId('573a13b1f29313caabd37187'),
#   'count': 2,
#   'title': 'Tony Takitani',
#   'year': 2004},
#  {'_id': ObjectId('573a1394f29313caabcdfc64'),
#   'count': 2,
#   'title': 'The End of the Affair',
#   'year': 1955},
#  {'_id': ObjectId('573a1397f29313caabce6d98'),
#   'count': 2,
#   'title': 'Newsfront',
#   'year': 1978},
#  {'_id': ObjectId('573a1394f29313caabce0cd7'),
#   'count': 2,
#   'title': 'Time Stood Still',
#   'year': 1959},
#  {'_id': ObjectId('573a13a6f29313caabd19b96'),
#   'count': 2,
#   'title': 'Aalavandhan',
#   'year': 2001},
#  {'_id': ObjectId('573a1397f29313caabce8a63'),
#   'count': 2,
#   'title': 'Flashdance',
#   'year': 1983},
#  {'_id': ObjectId('573a139ff29313caabd00251'),
#   'count': 2,
#   'title': "Lord's Lantern in Budapest",
#   'year': 1999},
#  {'_id': ObjectId('573a13d0f29313caabd8cf76'),
#   'count': 2,
#   'title': 'Miss Representation',
#   'year': 2011},
#  {'_id': ObjectId('573a13b9f29313caabd4f56b'),
#   'count': 2,
#   'title': 'Shadows',
#   'year': 2007},
#  {'_id': ObjectId('573a13c6f29313caabd7259e'),
#   'count': 2,
#   'title': 'Somewhere',
#   'year': 2010},
#  {'_id': ObjectId('573a13dff29313caabdb729b'),
#   'count': 2,
#   'title': 'American Promise',
#   'year': 2013},
#  {'_id': ObjectId('573a1396f29313caabce345f'),
#   'count': 2,
#   'title': 'Asfalttilampaat',
#   'year': 1968},
#  {'_id': ObjectId('573a1399f29313caabcecb4b'),
#   'count': 2,
#   'title': 'Robot Jox',
#   'year': 1989},
#  {'_id': ObjectId('573a13e9f29313caabdcc1fe'),
#   'count': 2,
#   'title': 'Suburban Gothic',
#   'year': 2014},
#  {'_id': ObjectId('573a1397f29313caabce6864'),
#   'count': 2,
#   'title': 'The Rescuers',
#   'year': 1977},
#  {'_id': ObjectId('573a13d7f29313caabda1b01'),
#   'count': 2,
#   'title': 'Monica Z',
#   'year': 2013},
#  {'_id': ObjectId('573a13bff29313caabd5e17a'),
#   'count': 2,
#   'title': 'Thirst',
#   'year': 2010},
#  {'_id': ObjectId('573a13def29313caabdb6bf5'),
#   'count': 2,
#   'title': 'The Russian Novel',
#   'year': 2012},
#  {'_id': ObjectId('573a1396f29313caabce3c8e'),
#   'count': 2,
#   'title': 'The Rain People',
#   'year': 1969},
#  {'_id': ObjectId('573a13b9f29313caabd4fa83'),
#   'count': 2,
#   'title': 'Semi-Pro',
#   'year': 2008},
#  {'_id': ObjectId('573a139bf29313caabcf405b'),
#   'count': 2,
#   'title': 'The Siege',
#   'year': 1998},
#  {'_id': ObjectId('573a13b2f29313caabd3a1b4'),
#   'count': 2,
#   'title': 'Quo Vadis, Baby?',
#   'year': 2005},
#  {'_id': ObjectId('573a13ccf29313caabd833ae'),
#   'count': 2,
#   'title': 'The Lost Bladesman',
#   'year': 2011},
#  {'_id': ObjectId('573a13b7f29313caabd4a026'),
#   'count': 2,
#   'title': 'We Are Marshall',
#   'year': 2006},
#  {'_id': ObjectId('573a139df29313caabcf97b9'),
#   'count': 2,
#   'title': 'Faithless',
#   'year': 2000},
#  {'_id': ObjectId('573a13b4f29313caabd40a3b'),
#   'count': 2,
#   'title': 'An American Girl Adventure',
#   'year': 2005},
#  {'_id': ObjectId('573a13a6f29313caabd19132'),
#   'count': 2,
#   'title': 'Visitor Q',
#   'year': 2001},
#  {'_id': ObjectId('573a13cbf29313caabd7fd18'),
#   'count': 2,
#   'title': "Bill Maher... But I'm Not Wrong",
#   'year': 2010},
#  {'_id': ObjectId('573a13c9f29313caabd796ed'),
#   'count': 2,
#   'title': 'Phobia 2',
#   'year': 2009},
#  {'_id': ObjectId('573a139ff29313caabd01907'),
#   'count': 2,
#   'title': 'The Bridge',
#   'year': 1999},
#  {'_id': ObjectId('573a13a0f29313caabd04642'),
#   'count': 2,
#   'title': 'The Princess and the Warrior',
#   'year': 2000},
#  {'_id': ObjectId('573a13c6f29313caabd72c23'),
#   'count': 2,
#   'title': 'Little Girl',
#   'year': 2009},
#  {'_id': ObjectId('573a1395f29313caabce29b7'),
#   'count': 2,
#   'title': 'Three',
#   'year': 1965},
#  {'_id': ObjectId('573a13bef29313caabd5b79b'),
#   'count': 2,
#   'title': 'Flash of Genius',
#   'year': 2008},
#  {'_id': ObjectId('573a13d8f29313caabda59d5'),
#   'count': 2,
#   'title': "Fanie Fourie's Lobola",
#   'year': 2013},
#  {'_id': ObjectId('573a13cdf29313caabd84e88'),
#   'count': 2,
#   'title': 'Der letzte schène Herbsttag',
#   'year': 2010},
#  {'_id': ObjectId('573a1394f29313caabcdf10b'),
#   'count': 2,
#   'title': 'Room for One More',
#   'year': 1952},
#  {'_id': ObjectId('573a13aef29313caabd2e06e'),
#   'count': 2,
#   'title': 'Bonjour Monsieur Shlomi',
#   'year': 2003},
#  {'_id': ObjectId('573a13d3f29313caabd95b57'),
#   'count': 2,
#   'title': 'Himizu',
#   'year': 2011},
#  {'_id': ObjectId('573a13b9f29313caabd4e68f'),
#   'count': 2,
#   'title': 'Sex, Party and Lies',
#   'year': 2009},
#  {'_id': ObjectId('573a13d8f29313caabda5bab'),
#   'count': 2,
#   'title': 'Isdraken',
#   'year': 2012},
#  {'_id': ObjectId('573a1394f29313caabce074b'),
#   'count': 2,
#   'title': "A Tailor's Maid",
#   'year': 1957},
#  {'_id': ObjectId('573a13a6f29313caabd18dd9'),
#   'count': 2,
#   'title': 'Hush!',
#   'year': 2001},
#  {'_id': ObjectId('573a1394f29313caabcdf7da'),
#   'count': 2,
#   'title': 'The Count of Monte Cristo',
#   'year': 1954},
#  {'_id': ObjectId('573a13b8f29313caabd4c8c5'),
#   'count': 2,
#   'title': 'Thor',
#   'year': 2011},
#  {'_id': ObjectId('573a1398f29313caabceb7cd'),
#   'count': 2,
#   'title': 'Johnny Handsome',
#   'year': 1989},
#  {'_id': ObjectId('573a13def29313caabdb5661'),
#   'count': 2,
#   'title': 'West',
#   'year': 2013},
#  {'_id': ObjectId('573a1398f29313caabce9df9'),
#   'count': 2,
#   'title': 'Big Trouble in Little China',
#   'year': 1986},
#  {'_id': ObjectId('573a13a5f29313caabd15bc9'),
#   'count': 2,
#   'title': 'Truly Human',
#   'year': 2001},
#  {'_id': ObjectId('573a13bff29313caabd5fa41'),
#   'count': 2,
#   'title': "What Doesn't Kill You",
#   'year': 2008},
#  {'_id': ObjectId('573a13c4f29313caabd6dec7'),
#   'count': 2,
#   'title': 'The House of Small Cubes',
#   'year': 2008},
#  {'_id': ObjectId('573a13e7f29313caabdc80cd'),
#   'count': 2,
#   'title': 'Prison Terminal: The Last Days of Private Jack Hall',
#   'year': 2013},
#  {'_id': ObjectId('573a139af29313caabcf015f'),
#   'count': 2,
#   'title': 'The Mirror',
#   'year': 1997},
#  {'_id': ObjectId('573a13c9f29313caabd79d8b'),
#   'count': 2,
#   'title': 'Melancholia',
#   'year': 2011},
#  {'_id': ObjectId('573a13c1f29313caabd64b87'),
#   'count': 2,
#   'title': 'Disaster Movie',
#   'year': 2008},
#  {'_id': ObjectId('573a1397f29313caabce7e47'),
#   'count': 2,
#   'title': 'Fear No Evil',
#   'year': 1981},
#  {'_id': ObjectId('573a1399f29313caabced582'),
#   'count': 2,
#   'title': 'Stop! Or My Mom Will Shoot',
#   'year': 1992},
#  {'_id': ObjectId('573a139cf29313caabcf69c8'),
#   'count': 2,
#   'title': 'The Jew in the Lotus',
#   'year': 1998},
#  ...]

# %% [markdown]
# #### Задача 2.2 — **1 балл**

# %% [markdown]
# Используя данные, полученные в задаче 2.1, выведите на экран столбчатую диаграмму, показывающую топ-20 наиболее комментируемых фильмов. По оси ординат выведите названия этих фильмов (подписи разместите слева диаграммы), по оси абсцисс — количество комментариев.
#
# Для решения задачи можно использовать любую библиотеку, например Seaborn или Matplotlib.

# %%
# Ваш код здесь
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
result_top20 = result[:20]
result_top20
# Out:
# [{'_id': ObjectId('573a13bff29313caabd5e91e'),
#   'count': 161,
#   'title': 'The Taking of Pelham 1 2 3',
#   'year': 2009},
#  {'_id': ObjectId('573a13b3f29313caabd3b647'),
#   'count': 158,
#   'title': 'Terminator Salvation',
#   'year': 2009},
#  {'_id': ObjectId('573a13a5f29313caabd159a9'),
#   'count': 158,
#   'title': 'About a Boy',
#   'year': 2002},
#  {'_id': ObjectId('573a13abf29313caabd25582'),
#   'count': 158,
#   'title': '50 First Dates',
#   'year': 2004},
#  {'_id': ObjectId('573a13a3f29313caabd0d1e3'),
#   'count': 158,
#   'title': "Ocean's Eleven",
#   'year': 2001},
#  {'_id': ObjectId('573a13bcf29313caabd57db6'),
#   'count': 157,
#   'title': 'Sherlock Holmes',
#   'year': 2009},
#  {'_id': ObjectId('573a139bf29313caabcf3a45'),
#   'count': 157,
#   'title': 'The Mummy',
#   'year': 1999},
#  {'_id': ObjectId('573a13b0f29313caabd3505e'),
#   'count': 155,
#   'title': 'Hellboy II: The Golden Army',
#   'year': 2008},
#  {'_id': ObjectId('573a13acf29313caabd289b3'),
#   'count': 154,
#   'title': 'Anchorman: The Legend of Ron Burgundy',
#   'year': 2004},
#  {'_id': ObjectId('573a13a0f29313caabd05ae1'),
#   'count': 154,
#   'title': 'The Mummy Returns',
#   'year': 2001},
#  {'_id': ObjectId('573a139df29313caabcfb008'),
#   'count': 153,
#   'title': 'American Pie',
#   'year': 1999},
#  {'_id': ObjectId('573a139af29313caabcf0f51'),
#   'count': 153,
#   'title': 'X-Men',
#   'year': 2000},
#  {'_id': ObjectId('573a139af29313caabcf0178'),
#   'count': 153,
#   'title': 'Mission: Impossible',
#   'year': 1996},
#  {'_id': ObjectId('573a13b3f29313caabd3de52'),
#   'count': 153,
#   'title': "Pirates of the Caribbean: At World's End",
#   'year': 2007},
#  {'_id': ObjectId('573a13a9f29313caabd1ea7d'),
#   'count': 153,
#   'title': 'Bruce Almighty',
#   'year': 2003},
#  {'_id': ObjectId('573a1397f29313caabce8413'),
#   'count': 153,
#   'title': 'E.T. the Extra-Terrestrial',
#   'year': 1982},
#  {'_id': ObjectId('573a13b6f29313caabd48454'),
#   'count': 153,
#   'title': 'Wanted',
#   'year': 2008},
#  {'_id': ObjectId('573a1394f29313caabcde63e'),
#   'count': 153,
#   'title': 'Cinderella',
#   'year': 1950},
#  {'_id': ObjectId('573a139ef29313caabcfd114'),
#   'count': 152,
#   'title': 'Gladiator',
#   'year': 2000},
#  {'_id': ObjectId('573a13a7f29313caabd1aa03'),
#   'count': 152,
#   'title': 'The Ring',
#   'year': 2002}]

# %%
years = []
counts = []
titles = []

for item in result_top20:
    years.append(item['year'])
    counts.append(item['count'])
    titles.append(item['title'])

# %%
plt.barh(
    titles, counts
)
plt.xlabel('Количество комментариев')
plt.ylabel('Название фильма')
plt.title('Топ-20 наиболее комментируемых фильмов')
plt.gca().invert_yaxis()
plt.show()
